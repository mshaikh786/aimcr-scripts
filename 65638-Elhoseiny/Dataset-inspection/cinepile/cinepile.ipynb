# %%
# =========================
# Cell 1 — Auth + config
# =========================
import os, math, random, json
import requests

from huggingface_hub import HfApi

DATASET_ID = "tomg-group-umd/cinepile"   # change if needed
SEED = 42
SHUFFLE_BUFFER = 10_000                 # streaming shuffle buffer
MAX_VIZ = 24                            # max items to show in a grid

DATASETS_SERVER = "https://datasets-server.huggingface.co"

def hf_token_from_env():
    for k in ("HF_TOKEN", "HUGGINGFACE_HUB_TOKEN", "HF_ACCESS_TOKEN"):
        v = os.getenv(k)
        if v:
            return v.strip()
    return None

HF_TOKEN = hf_token_from_env()
assert HF_TOKEN, "No HF token found in env vars (HF_TOKEN / HUGGINGFACE_HUB_TOKEN / HF_ACCESS_TOKEN)."

HEADERS = {"Authorization": f"Bearer {HF_TOKEN}"}

api = HfApi(token=HF_TOKEN)
print("whoami:", api.whoami()["name"])
print("dataset:", api.dataset_info(DATASET_ID).id)
# Out:
# whoami: Tarnimat
# dataset: tomg-group-umd/cinepile

# %%
# =========================
# Cell 2 — Sampling scheme + dataset-server helpers
# =========================
def sampling_fraction(n: int) -> float:
    # Scheme:
    # 1%    for ≤10,000
    # 0.1%  for ≤100,000
    # 0.01% for ≤1,000,000
    # 0.001% for ≤10,000,000
    if n <= 10_000:
        return 0.01
    if n <= 100_000:
        return 0.001
    if n <= 1_000_000:
        return 0.0001
    if n <= 10_000_000:
        return 0.00001
    return 0.000001  # >10M

def get_splits(dataset_id: str):
    r = requests.get(
        f"{DATASETS_SERVER}/splits",
        params={"dataset": dataset_id},
        headers=HEADERS,
        timeout=60,
    )
    r.raise_for_status()
    return r.json()["splits"]  # list of dicts: {config, split, num_examples? ...}

def get_num_rows(dataset_id: str, config: str, split: str) -> int:
    """
    Robust across dataset-server JSON shapes:
    - Sometimes size has size.num_rows
    - Often size has size.splits[] each with {split, num_rows, num_bytes}
    """
    r = requests.get(
        f"{DATASETS_SERVER}/size",
        params={"dataset": dataset_id, "config": config},  # NOTE: no split here
        headers=HEADERS,
        timeout=60,
    )
    r.raise_for_status()
    j = r.json()
    size = j.get("size", {})

    if "num_rows" in size:
        return int(size["num_rows"])

    for s in size.get("splits", []):
        if s.get("split") == split and "num_rows" in s:
            return int(s["num_rows"])

    raise KeyError(f"Could not find num_rows for config='{config}', split='{split}'. size keys={list(size.keys())}")

# %%
# =========================
# Cell 3 — Build sampling plans (ALL configs)
# =========================
splits = get_splits(DATASET_ID)

print("Available configs/splits:")
for s in splits:
    print(f"- config={s['config']} split={s['split']} num_examples={s.get('num_examples')}")

# unique configs
configs = sorted({s["config"] for s in splits})

plans = {}  # config -> list[(split, N, frac, K)]
for cfg in configs:
    targets = []
    for s in splits:
        if s["config"] != cfg:
            continue
        split = s["split"]
        n = get_num_rows(DATASET_ID, cfg, split)
        frac = sampling_fraction(n)
        k = max(1, int(math.ceil(n * frac)))
        targets.append((split, n, frac, k))
    plans[cfg] = targets

print("\nSampling plan per config:")
for cfg, targets in plans.items():
    print(f"\nCONFIG={cfg}")
    for split, n, frac, k in targets:
        print(f"  - {split}: N={n:,} -> frac={frac:g} -> K={k:,}")
# Out:
# Available configs/splits:
# - config=v2 split=train num_examples=None
# - config=v2 split=test num_examples=None
# - config=v1 split=train num_examples=None
# - config=v1 split=test num_examples=None
#
# Sampling plan per config:
#
# CONFIG=v1
#   - train: N=298,888 -> frac=0.0001 -> K=30
#   - test: N=4,941 -> frac=0.01 -> K=50
#
# CONFIG=v2
#   - train: N=298,888 -> frac=0.0001 -> K=30
#   - test: N=4,941 -> frac=0.01 -> K=50

# %%
# =========================
# Cell 4 — Streaming sampler (downloads ONLY what you iterate over)
# =========================
from datasets import load_dataset

def take_k_streaming(dataset_id: str, config: str, split: str, k: int, seed: int = 42, buffer_size: int = 10_000):
    ds = load_dataset(dataset_id, config, split=split, streaming=True)
    ds = ds.shuffle(seed=seed, buffer_size=buffer_size)
    return list(ds.take(k))

# %%
# =========================
# Cell 5 — Visualization (image grid if possible, else text preview)
# =========================
import io
import matplotlib.pyplot as plt
from PIL import Image

def find_image_columns(example: dict):
    cols = []
    for k, v in example.items():
        if v is None:
            continue
        if isinstance(v, dict) and ("bytes" in v or "path" in v):
            cols.append(k)
        elif isinstance(v, Image.Image):
            cols.append(k)
    return cols

def to_pil(v):
    if v is None:
        return None
    if isinstance(v, dict):
        if v.get("bytes") is not None:
            return Image.open(io.BytesIO(v["bytes"])).convert("RGB")
        if v.get("path"):
            return Image.open(v["path"]).convert("RGB")
    if isinstance(v, Image.Image):
        return v.convert("RGB")
    return None

def visualize_samples(samples, max_viz: int = 24):
    if not samples:
        print("No samples to visualize.")
        return

    img_cols = find_image_columns(samples[0])
    if not img_cols:
        print("No image-like columns detected. Showing text preview:")
        for i, ex in enumerate(samples[:10]):
            print(f"\n--- sample {i} ---")
            for k in list(ex.keys())[:12]:
                s = str(ex[k])
                print(f"{k}: {s[:250]}{'...' if len(s) > 250 else ''}")
        return

    col = img_cols[0]
    imgs = []
    for ex in samples[:max_viz]:
        img = to_pil(ex.get(col))
        if img is not None:
            imgs.append(img)

    if not imgs:
        print(f"Detected '{col}' but couldn't decode images. Showing text preview instead.")
        return

    n = len(imgs)
    cols = 6
    rows = math.ceil(n / cols)
    plt.figure(figsize=(cols * 3, rows * 3))
    for i, img in enumerate(imgs):
        ax = plt.subplot(rows, cols, i + 1)
        ax.imshow(img)
        ax.axis("off")
    plt.tight_layout()
    plt.show()

# %%
# =========================
# Cell 6 — Run sampling + visualization (per config/split)
# =========================
# Example: sample both configs and both splits (train/test) and visualize each

for cfg, targets in plans.items():
    print(f"\n====================\nCONFIG={cfg}\n====================")
    for split, n, frac, k in targets:
        print(f"\n-> Sampling split='{split}' with K={k} (N={n:,}, frac={frac:g})")
        samples = take_k_streaming(DATASET_ID, cfg, split, k, seed=SEED, buffer_size=SHUFFLE_BUFFER)
        print("Collected:", len(samples))
        visualize_samples(samples, max_viz=MAX_VIZ)
# Out:
# ====================
# CONFIG=v1
# ====================
#
# -> Sampling split='train' with K=30 (N=298,888, frac=0.0001)
# README.md:   0%|          | 0.00/6.68k [00:00<?, ?B/s]
# Collected: 30
# No image-like columns detected. Showing text preview:
#
# --- sample 0 ---
# movie_name: Small Soldiers
# year: 1998
# genre: ['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi']
# yt_clip_title: Small Soldiers (7/10) Movie CLIP - I Always Hated These Things (1998) HD
# yt_clip_link: https://youtube.com/watch?v=n7KKfjFRw8w
# movie_scene: <subtitle> You all right?
# <subtitle> All my makeup is cruelty free.
# <subtitle> You come here often?
# <subtitle> Will you take me to the prom?
# <visual descriptions> The dolls attack him.
# <subtitle> If you can't accessorize, pulverize.
# <subtitle> You've...
# subtitles: <subtitle> You all right?
# <subtitle> All my makeup is cruelty free.
# <subtitle> You come here often?
# <subtitle> Will you take me to the prom?
# <subtitle> If you can't accessorize, pulverize.
# <subtitle> You've been a bad boy.
# <subtitle> And now, you mus...
# question: Where does Archer hide?
# choices: ['Under the bed', 'Behind the couch', 'In the closet', "In Ellen's backpack", 'In the attic']
# answer_key: In Ellen's backpack
# answer_key_position: 3
# question_category: Character and
# Relationship Dynamics
#
# --- sample 1 ---
# movie_name: Spider-Man: No Way Home
# year: 2021
# genre: ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: No Way Home (2021) - Green Goblin & Aunt May Scene | Movieclips
# yt_clip_link: https://youtube.com/watch?v=HJqFPeBWftc
# movie_scene: <subtitle> Coward!
# <subtitle> We have a new world to conquer.
# <visual descriptions> He turns to the mask.
# <subtitle> You make me sick.
# <subtitle> Leave me alone.
# <subtitle> Please.
# <visual descriptions> Hiding in the shadows.
# <subtitle> Hiding from w...
# subtitles: <subtitle> Coward!
# <subtitle> We have a new world to conquer.
# <subtitle> You make me sick.
# <subtitle> Leave me alone.
# <subtitle> Please.
# <subtitle> Hiding from who you truly are.
# <subtitle> No!
# <subtitle> You can't escape yourself.
# <subtitle> Hey, Ma...
# question: Which character assumes an unexpected role in the scene?
# choices: ['May', 'Mysterio', 'Spider-Man', 'Norman', 'Peter']
# answer_key: Norman
# answer_key_position: 3
# question_category: Character and
# Relationship Dynamics
#
# --- sample 2 ---
# movie_name: Spider-Man: Far from Home
# year: 2019
# genre: ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: Far From Home (2019) - Inside Mysterio's Illusion Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=j4onAJ-3FAM
# movie_scene: <subtitle> That's awesome!
# <visual descriptions> Within the illusion, Peter sticks webs onto a drone.
# <visual descriptions> He leaps between several others, connecting them with strands of web.
# <visual descriptions> Beck looks at the screen on his wr...
# subtitles: <subtitle> That's awesome!
# <subtitle> William, I've got drones breaking formation.
# <subtitle> Well, maybe they hit a flock of birds or something.
# <subtitle> You're fine.
# <subtitle> Well, I want to see what's happening there.
# <subtitle> I'm taking man...
# question: What action does Peter take to disable the drones?
# choices: ['Traps them in a net', 'Explodes them with a bomb', 'Hacks their systems', 'Shoots them with a web', 'Electrocutes them with webs']
# answer_key: Electrocutes them with webs
# answer_key_position: 4
# question_category: Setting and
# Technical Analysis
#
# --- sample 3 ---
# movie_name: Soul Surfer
# year: 2011
# genre: ['Biography', 'Drama', 'Family', 'Sport']
# yt_clip_title: Soul Surfer #11 Movie CLIP - A Prosthetic Arm (2011) HD
# yt_clip_link: https://youtube.com/watch?v=exclwIbllXQ
# movie_scene: <subtitle> Wait, wait, wait.
# <subtitle> She's been home for five minutes.
# <subtitle> They're gonna pay for the entire thing.
# <subtitle> How did you talk to a TV show?
# <subtitle> And it's custom-made.
# <subtitle> Will it look normal?
# <subtitle> I would...
# subtitles: <subtitle> Wait, wait, wait.
# <subtitle> She's been home for five minutes.
# <subtitle> They're gonna pay for the entire thing.
# <subtitle> How did you talk to a TV show?
# <subtitle> And it's custom-made.
# <subtitle> Will it look normal?
# <subtitle> I would...
# question: What is expected to be gained by giving the interview?
# choices: ['Fame', 'A chance to be on TV', 'A chance to surf with the arm', 'Money', 'A custom-made arm']
# answer_key: A custom-made arm
# answer_key_position: 4
# question_category: Narrative and
# Plot Analysis
#
# --- sample 4 ---
# movie_name: Soul Food
# year: 1997
# genre: ['Comedy', 'Drama']
# yt_clip_title: Soul Food (4/5) Movie CLIP - Y'all Messed Up the Family! (1997) HD
# yt_clip_link: https://youtube.com/watch?v=RRcYHJ1uTro
# movie_scene: <subtitle> What are you talking about?
# <subtitle> Supposedly, Mama has some large amount of money stashed someplace in the house that she was saving for Ahmaud.
# <visual descriptions> In the kitchen, Ahmaud dries his hands and listens.
# <subtitle> Ahma...
# subtitles: <subtitle> What are you talking about?
# <subtitle> Supposedly, Mama has some large amount of money stashed someplace in the house that she was saving for Ahmaud.
# <subtitle> Ahmaud!
# <subtitle> Get in here!
# <subtitle> Ahmaud!
# <subtitle> Right now!
# <subt...
# question: What is the predominant color of Ahmaud's attire in the scene?
# choices: ['Black', 'Blue', 'Yellow', 'Red', 'Green']
# answer_key: Black
# answer_key_position: 0
# question_category: Character and
# Relationship Dynamics
#
# --- sample 5 ---
# movie_name: Spontaneous
# year: 2020
# genre: ['Comedy', 'Drama', 'Horror', 'Romance']
# yt_clip_title: Spontaneous (2020) - I Really Wanna Kiss You Scene (3/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=nCT_FTjquzA
# movie_scene: <subtitle> What do you think does?
# <subtitle> Um, I don't know.
# <subtitle> That's not good enough.
# <subtitle> No.
# <subtitle> The cosmic bullshit of the universe, right?
# <subtitle> Lame!
# <subtitle> I'm sorry.
# <visual descriptions> They walk across the...
# subtitles: <subtitle> What do you think does?
# <subtitle> Um, I don't know.
# <subtitle> That's not good enough.
# <subtitle> No.
# <subtitle> The cosmic bullshit of the universe, right?
# <subtitle> Lame!
# <subtitle> I'm sorry.
# <subtitle> I'm writing this book called Al...
# question: How many times does Dylan ask Mara a question?
# choices: ['1', '5', '2', '3', '4']
# answer_key: 2
# answer_key_position: 2
# question_category: Temporal
#
# --- sample 6 ---
# movie_name: Small Soldiers
# year: 1998
# genre: ['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi']
# yt_clip_title: Small Soldiers (3/10) Movie CLIP - Keeper of Encarta (1998) HD
# yt_clip_link: https://youtube.com/watch?v=TgZwFvKRqK4
# movie_scene: <subtitle> Hey!
# <subtitle> What the heck are you?
# <subtitle> You're not like any toy I've ever seen.
# <subtitle> Come on, speak up.
# <subtitle> Greetings, Alan.
# <subtitle> Now shut up.
# <subtitle> I am Archer, emissary of the Gorgonites.
# <subtitle> Mm-h...
# subtitles: <subtitle> Hey!
# <subtitle> What the heck are you?
# <subtitle> You're not like any toy I've ever seen.
# <subtitle> Come on, speak up.
# <subtitle> Greetings, Alan.
# <subtitle> Now shut up.
# <subtitle> I am Archer, emissary of the Gorgonites.
# <subtitle> Mm-h...
# question: Where is Alan in relation to Archer at the end of the scene?
# choices: ['Standing next to him', 'Sitting across from him', 'In front of him', 'Behind him', 'Not present']
# answer_key: In front of him
# answer_key_position: 2
# question_category: Character and
# Relationship Dynamics
#
# --- sample 7 ---
# movie_name: Spider-Man: Into the Spider-Verse
# year: 2018
# genre: ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: Into the Spider-Verse (2018) - Miles vs. Kingpin Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=XMKKYshEbzM
# movie_scene: <subtitle> Not so easy doing it on your own, is it?
# <visual descriptions> Kingpin slams Miles against a window.
# <subtitle> I can't wait to kill one more Spider-Man.
# <visual descriptions> Glitching images of Vanessa and Richard appear.
# <visual descrip...
# subtitles: <subtitle> Not so easy doing it on your own, is it?
# <subtitle> I can't wait to kill one more Spider-Man.
# <subtitle> What?
# <subtitle> Wilson.
# <subtitle> Is this what you want, man?
# <subtitle> What are you doing?
# <subtitle> Stay away from me.
# <subtitle...
# question: What is Kingpin's motive for wanting to kill another Spider-Man?
# choices: ['To assert dominance.', 'To eliminate competition.', 'To seek revenge.', 'To gain power.', 'To protect Vanessa and Richard.']
# answer_key: To seek revenge.
# answer_key_position: 2
# question_category: Narrative and
# Plot Analysis
#
# --- sample 8 ---
# movie_name: Snatch
# year: 2000
# genre: ['Comedy', 'Crime']
# yt_clip_title: The Definition of Nemesis - Snatch (6/8) Movie CLIP (2000) HD
# yt_clip_link: https://youtube.com/watch?v=xu0p6CtioZk
# movie_scene: <subtitle> Well, thank you for that.
# <subtitle> That's a great weight off my mind.
# <subtitle> Now, I mean, if you wouldn't mind telling me who the fuck you are, apart from someone who feeds people to pigs, of course.
# <subtitle> Do you know what nemes...
# subtitles: <subtitle> Well, thank you for that.
# <subtitle> That's a great weight off my mind.
# <subtitle> Now, I mean, if you wouldn't mind telling me who the fuck you are, apart from someone who feeds people to pigs, of course.
# <subtitle> Do you know what nemes...
# question: What happens between the nemesis speech and the character opening the door?
# choices: ['The character asks who the other person is.', 'The character steps over the body.', 'The character feeds someone to pigs.', 'The character says "gentlemen."', 'The character says "thank you."']
# answer_key: The character steps over the body.
# answer_key_position: 1
# question_category: Temporal
#
# --- sample 9 ---
# movie_name: Smallfoot
# year: 2018
# genre: ['Animation', 'Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Musical']
# yt_clip_title: Smallfoot (2018) - Let It Lie Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=kF6apcTT-j8
# movie_scene: <subtitle> You see me, yo.
# <subtitle> There was a time when yetis lived beneath the clouds.
# <subtitle> We were alive and we were thriving till we came across a crowd of smallfoot.
# <subtitle> That's right, we used to live down there.
# <subtitle> But th...
# subtitles: <subtitle> You see me, yo.
# <subtitle> There was a time when yetis lived beneath the clouds.
# <subtitle> We were alive and we were thriving till we came across a crowd of smallfoot.
# <subtitle> That's right, we used to live down there.
# <subtitle> But th...
# question: What is the correct sequence of events in the scene?
# choices: ['Laws were written, humans attacked yetis, and yetis climbed the mountain.', 'Yeti lived beneath the clouds, encountered humans, and climbed the mountain.', 'Humans attacked yetis, laws were written, and yetis climbed the mountain.', 'Yetis climbed ...
# answer_key: Yeti lived beneath the clouds, encountered humans, and climbed the mountain.
# answer_key_position: 1
# question_category: Temporal
#
# -> Sampling split='test' with K=50 (N=4,941, frac=0.01)
# Collected: 50
# No image-like columns detected. Showing text preview:
#
# --- sample 0 ---
# movie_name: Rings
# year: 2017
# genre: ['Drama', 'Horror', 'Mystery', 'Romance']
# yt_clip_title: Rings (2017) - It's Never Over Scene (10/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=pN5RlyFWJBA
# movie_scene: <subtitle> Our souls are eternal.
# <subtitle> And when we die, the spirit strives to find a new home.
# <subtitle> I'm telling you, she's coming back.
# <subtitle> This time for real.
# <subtitle> you were never afraid of.
# <subtitle> Just because you had a ...
# subtitles: <subtitle> Our souls are eternal.
# <subtitle> And when we die, the spirit strives to find a new home.
# <subtitle> I'm telling you, she's coming back.
# <subtitle> This time for real.
# <subtitle> you were never afraid of.
# <subtitle> Just because you had a ...
# question: What is Julia doing when the cicada crawls out?
# choices: ['Standing', 'Lying', 'Leaning', 'Sitting', 'Kneeling']
# answer_key: Leaning
# answer_key_position: 2
# question_category: Setting and
# Technical Analysis
#
# --- sample 1 ---
# movie_name: Delta Farce
# year: 2007
# genre: ['Action', 'Adventure', 'Comedy']
# yt_clip_title: Delta Farce (3/9) Movie CLIP - Butcher of Baghdad (2007) HD
# yt_clip_link: https://youtube.com/watch?v=9_AMztckp6k
# movie_scene: <subtitle> Come on!
# <subtitle> Get some!
# <subtitle> Get some!
# <subtitle> All right, ladies.
# <subtitle> Let's get her done.
# <visual descriptions> The Humvee pulls away, revealing a broken road sign underneath.
# <visual descriptions> Mexico City, 500 ki...
# subtitles: <subtitle> Come on!
# <subtitle> Get some!
# <subtitle> Get some!
# <subtitle> All right, ladies.
# <subtitle> Let's get her done.
# <subtitle> All right, y'all, let's fan out.
# <subtitle> I'll secure the perimeter.
# <subtitle> That Charlie's a real sneaky basta...
# question: How does Larry interact with the Humvee?
# choices: ['He drives it.', 'He cleans it.', 'He sells it.', 'He buys it.', 'He repairs it.']
# answer_key: He drives it.
# answer_key_position: 0
# question_category: Setting and
# Technical Analysis
#
# --- sample 2 ---
# movie_name: Deuce Bigalow: European Gigolo
# year: 2005
# genre: ['Comedy']
# yt_clip_title: Deuce Bigalow: European Gigolo (2005) - Chicken and Waffles Scene (3/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=-kHMOXNsE2k
# movie_scene: <subtitle> TJ, thank God you're here.
# <subtitle> How'd you find me?
# <subtitle> It's the only chicken and waffle place in all of Holland.
# <subtitle> So a black man's gotta be at a chicken and waffles place.
# <subtitle> That's racist.
# <subtitle> But you...
# subtitles: <subtitle> TJ, thank God you're here.
# <subtitle> How'd you find me?
# <subtitle> It's the only chicken and waffle place in all of Holland.
# <subtitle> So a black man's gotta be at a chicken and waffles place.
# <subtitle> That's racist.
# <subtitle> But you...
# question: What is the tone of TJ's speech when he says, "That's racist"?
# choices: ['Sarcastic', 'Angry', 'Indifferent', 'Humorous', 'Sad']
# answer_key: Sarcastic
# answer_key_position: 0
# question_category: Character and
# Relationship Dynamics
#
# --- sample 3 ---
# movie_name: Buddy Games
# year: 2019
# genre: ['Comedy']
# yt_clip_title: Buddy Games (2020) - Man-Juice Pina Coladas Scene (5/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=fslJEzCX2-k
# movie_scene: <subtitle> Can I get you anything?
# <subtitle> Another near beer?
# <subtitle> No, I'm good.
# <subtitle> Okay.
# <subtitle> You know what, though?
# <subtitle> I'm gonna get you something.
# <subtitle> Okay.
# <subtitle> Show you how I feel about everything.
# <su...
# subtitles: <subtitle> Can I get you anything?
# <subtitle> Another near beer?
# <subtitle> No, I'm good.
# <subtitle> Okay.
# <subtitle> You know what, though?
# <subtitle> I'm gonna get you something.
# <subtitle> Okay.
# <subtitle> Show you how I feel about everything.
# <su...
# question: What is the setting where the guys hang out?
# choices: ['Living room', 'Bedroom', 'Fireplace', 'Kitchen', 'Bathroom']
# answer_key: Fireplace
# answer_key_position: 2
# question_category: Setting and
# Technical Analysis
#
# --- sample 4 ---
# movie_name: Barb Wire
# year: 1996
# genre: ['Action', 'Sci-Fi']
# yt_clip_title: Barb Wire (5/10) Movie CLIP - Package Check (1996) HD
# yt_clip_link: https://youtube.com/watch?v=n9L9jMlulXI
# movie_scene: <subtitle> You, you, or you!
# <subtitle> Just give me my drink!
# <subtitle> Sir, we're not open yet.
# <subtitle> I think you've had enough already.
# <subtitle> Ah, blow me.
# <subtitle> Camille, package check.
# <visual descriptions> Camille runs up and bite...
# subtitles: <subtitle> You, you, or you!
# <subtitle> Just give me my drink!
# <subtitle> Sir, we're not open yet.
# <subtitle> I think you've had enough already.
# <subtitle> Ah, blow me.
# <subtitle> Camille, package check.
# <subtitle> Get her off!
# <subtitle> Get her off...
# question: How does the conflict between the man and the staff unfold?
# choices: ['The man is given a warning', 'The man is asked to leave politely', 'The man is bitten and dragged out', 'The man is ignored by the staff', 'The man is served a drink']
# answer_key: The man is bitten and dragged out
# answer_key_position: 2
# question_category: Narrative and
# Plot Analysis
#
# --- sample 5 ---
# movie_name: Ouija
# year: 2014
# genre: ['Horror', 'Mystery', 'Thriller']
# yt_clip_title: Ouija (7/10) Movie CLIP - We Shouldn't Be Here (2014) HD
# yt_clip_link: https://youtube.com/watch?v=CDiosBMzR_c
# movie_scene: <subtitle> We should just leave.
# <subtitle> We shouldn't be here.
# <subtitle> What?
# <subtitle> The shadow?
# <visual descriptions> The shadow attacks Trevor.
# <visual descriptions> A force drags Trevor through a doorway into a dark room, then slams him i...
# subtitles: <subtitle> We should just leave.
# <subtitle> We shouldn't be here.
# <subtitle> What?
# <subtitle> The shadow?
# <subtitle> Trevor!
# <subtitle> Pete!
# <subtitle> Trevor!
# <subtitle> Pete!
# <subtitle> Lane!
# <subtitle> Keep going!
# <subtitle> Sarah, I need your he...
# question: How does the discovery of the mummified corpse impact the characters?
# choices: ['It leads them to a hidden treasure', 'It reveals a coded message', 'It provides a magical artifact', 'It triggers a trap', 'It frightens them']
# answer_key: It frightens them
# answer_key_position: 4
# question_category: Narrative and
# Plot Analysis
#
# --- sample 6 ---
# movie_name: Ouija
# year: 2014
# genre: ['Horror', 'Mystery', 'Thriller']
# yt_clip_title: Ouija (9/10) Movie CLIP - You Have to Play (2014) HD
# yt_clip_link: https://youtube.com/watch?v=m3262E3sfb8
# movie_scene: <subtitle> Let's burn this damn thing already.
# <visual descriptions> Sarah gets dragged through the small wall opening.
# <subtitle> Sarah!
# <subtitle> Sarah!
# <visual descriptions> In the dark chamber, candles light spontaneously.
# <visual descriptions> ...
# subtitles: <subtitle> Let's burn this damn thing already.
# <subtitle> Sarah!
# <subtitle> Sarah!
# <subtitle> As friends we've gathered, hearts are true.
# <subtitle> Spirit's near, we call to you.
# <subtitle> Doris, I'm playing alone, you have to play!
# <subtitle> Dori...
# question: What significant action does Sarah take to resolve her conflict by the end of the scene?
# choices: ['Sarah burns the bundle in the furnace.', 'Sarah confronts the decayed female form.', 'Sarah calls for help.', 'Sarah uses the Ouija board to communicate with spirits.', 'Sarah hides in the dark chamber.']
# answer_key: Sarah burns the bundle in the furnace.
# answer_key_position: 0
# question_category: Narrative and
# Plot Analysis
#
# --- sample 7 ---
# movie_name: Jack and Jill
# year: 2011
# genre: ['Comedy']
# yt_clip_title: Jack and Jill (2011) - Felipe's Family Scene (4/6) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=sk82NsHwkts
# movie_scene: <subtitle> This is my friend Jill.
# <subtitle> That's my father, my mama, my brother Juan, my other brother Juan, Juan Jr., my sister Juanita, my grandma Juangelina, and that... I'm kidding!
# <subtitle> I was gonna say, that's a lot of Juan!
# <subtitle>...
# subtitles: <subtitle> This is my friend Jill.
# <subtitle> That's my father, my mama, my brother Juan, my other brother Juan, Juan Jr., my sister Juanita, my grandma Juangelina, and that... I'm kidding!
# <subtitle> I was gonna say, that's a lot of Juan!
# <subtitle>...
# question: What action does Jill perform to entertain the crowd?
# choices: ['Does a dance', 'Plays an instrument', 'Reads a poem', 'Sings a song', 'Tells a joke']
# answer_key: Does a dance
# answer_key_position: 0
# question_category: Setting and
# Technical Analysis
#
# --- sample 8 ---
# movie_name: Cats & Dogs: The Revenge of Kitty Galore
# year: 2010
# genre: ['Action', 'Comedy', 'Family', 'Fantasy']
# yt_clip_title: Cats & Dogs: The Revenge of Kitty Galore #7 Movie CLIP - I Think I Like You (2010) HD
# yt_clip_link: https://youtube.com/watch?v=a88BNDMlPSE
# movie_scene: <subtitle> There's got to be a way out of here.
# <subtitle> Catherine, listen.
# <subtitle> Since this is the end, I guess I can say I think I might like you.
# <subtitle> Dig, stop.
# <subtitle> No, don't say anything.
# <subtitle> I know it's uncomfortable ...
# subtitles: <subtitle> There's got to be a way out of here.
# <subtitle> Catherine, listen.
# <subtitle> Since this is the end, I guess I can say I think I might like you.
# <subtitle> Dig, stop.
# <subtitle> No, don't say anything.
# <subtitle> I know it's uncomfortable ...
# question: What is the primary plan of escape for the characters in the scene?
# choices: ['Fighting their way out', 'Using a secret door', 'Waiting for rescue', 'Calling for help', 'Using a collar to pick a lock']
# answer_key: Using a collar to pick a lock
# answer_key_position: 4
# question_category: Character and
# Relationship Dynamics
#
# --- sample 9 ---
# movie_name: Daddy Day Camp
# year: 2007
# genre: ['Comedy', 'Family']
# yt_clip_title: Daddy Day Camp (2007) - Rock Wall Climb Scene (10/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=NN0GuXudBL8
# movie_scene: <subtitle> It's okay.
# <subtitle> It's okay, son.
# <subtitle> I told you, you're a loser, just like your old man.
# <subtitle> You're not a loser, Ben!
# <subtitle> He greased the wall!
# <subtitle> He's cheating!
# <subtitle> No, don't listen to her!
# <subtitl...
# subtitles: <subtitle> It's okay.
# <subtitle> It's okay, son.
# <subtitle> I told you, you're a loser, just like your old man.
# <subtitle> You're not a loser, Ben!
# <subtitle> He greased the wall!
# <subtitle> He's cheating!
# <subtitle> No, don't listen to her!
# <subtitl...
# question: What action does Ben take after sprinting to the tree?
# choices: ['Jumps', 'Hides', 'Calls for help', 'Rests', 'Climbs']
# answer_key: Climbs
# answer_key_position: 4
# question_category: Setting and
# Technical Analysis
#
# ====================
# CONFIG=v2
# ====================
#
# -> Sampling split='train' with K=30 (N=298,888, frac=0.0001)
# Collected: 30
# No image-like columns detected. Showing text preview:
#
# --- sample 0 ---
# movie_name: Small Soldiers
# year: 1998
# genre: ['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi']
# yt_clip_title: Small Soldiers (7/10) Movie CLIP - I Always Hated These Things (1998) HD
# yt_clip_link: https://youtube.com/watch?v=n7KKfjFRw8w
# movie_scene: <subtitle> You all right?
# <subtitle> All my makeup is cruelty free.
# <subtitle> You come here often?
# <subtitle> Will you take me to the prom?
# <visual descriptions> The dolls attack him.
# <subtitle> If you can't accessorize, pulverize.
# <subtitle> You've...
# subtitles: <subtitle> You all right?
# <subtitle> All my makeup is cruelty free.
# <subtitle> You come here often?
# <subtitle> Will you take me to the prom?
# <subtitle> If you can't accessorize, pulverize.
# <subtitle> You've been a bad boy.
# <subtitle> And now, you mus...
# question: Where does Archer hide?
# choices: ['Under the bed', 'Behind the couch', 'In the closet', "In Ellen's backpack", 'In the attic']
# answer_key: In Ellen's backpack
# answer_key_position: 3
# question_category: Character and
# Relationship Dynamics
#
# --- sample 1 ---
# movie_name: Spider-Man: No Way Home
# year: 2021
# genre: ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: No Way Home (2021) - Green Goblin & Aunt May Scene | Movieclips
# yt_clip_link: https://youtube.com/watch?v=HJqFPeBWftc
# movie_scene: <subtitle> Coward!
# <subtitle> We have a new world to conquer.
# <visual descriptions> He turns to the mask.
# <subtitle> You make me sick.
# <subtitle> Leave me alone.
# <subtitle> Please.
# <visual descriptions> Hiding in the shadows.
# <subtitle> Hiding from w...
# subtitles: <subtitle> Coward!
# <subtitle> We have a new world to conquer.
# <subtitle> You make me sick.
# <subtitle> Leave me alone.
# <subtitle> Please.
# <subtitle> Hiding from who you truly are.
# <subtitle> No!
# <subtitle> You can't escape yourself.
# <subtitle> Hey, Ma...
# question: Which character assumes an unexpected role in the scene?
# choices: ['May', 'Mysterio', 'Spider-Man', 'Norman', 'Peter']
# answer_key: Norman
# answer_key_position: 3
# question_category: Character and
# Relationship Dynamics
#
# --- sample 2 ---
# movie_name: Spider-Man: Far from Home
# year: 2019
# genre: ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: Far From Home (2019) - Inside Mysterio's Illusion Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=j4onAJ-3FAM
# movie_scene: <subtitle> That's awesome!
# <visual descriptions> Within the illusion, Peter sticks webs onto a drone.
# <visual descriptions> He leaps between several others, connecting them with strands of web.
# <visual descriptions> Beck looks at the screen on his wr...
# subtitles: <subtitle> That's awesome!
# <subtitle> William, I've got drones breaking formation.
# <subtitle> Well, maybe they hit a flock of birds or something.
# <subtitle> You're fine.
# <subtitle> Well, I want to see what's happening there.
# <subtitle> I'm taking man...
# question: What action does Peter take to disable the drones?
# choices: ['Traps them in a net', 'Explodes them with a bomb', 'Hacks their systems', 'Shoots them with a web', 'Electrocutes them with webs']
# answer_key: Electrocutes them with webs
# answer_key_position: 4
# question_category: Setting and
# Technical Analysis
#
# --- sample 3 ---
# movie_name: Soul Surfer
# year: 2011
# genre: ['Biography', 'Drama', 'Family', 'Sport']
# yt_clip_title: Soul Surfer #11 Movie CLIP - A Prosthetic Arm (2011) HD
# yt_clip_link: https://youtube.com/watch?v=exclwIbllXQ
# movie_scene: <subtitle> Wait, wait, wait.
# <subtitle> She's been home for five minutes.
# <subtitle> They're gonna pay for the entire thing.
# <subtitle> How did you talk to a TV show?
# <subtitle> And it's custom-made.
# <subtitle> Will it look normal?
# <subtitle> I would...
# subtitles: <subtitle> Wait, wait, wait.
# <subtitle> She's been home for five minutes.
# <subtitle> They're gonna pay for the entire thing.
# <subtitle> How did you talk to a TV show?
# <subtitle> And it's custom-made.
# <subtitle> Will it look normal?
# <subtitle> I would...
# question: What is the specific reason the character agrees to participate in the interview in the scene?
# choices: ['To gain celebrity status', 'To receive a custom-made item', 'To get compensated financially', 'To fulfil a personal ambition', 'To support a family member']
# answer_key: To receive a custom-made item
# answer_key_position: 1
# question_category: Narrative and
# Plot Analysis
#
# --- sample 4 ---
# movie_name: Soul Food
# year: 1997
# genre: ['Comedy', 'Drama']
# yt_clip_title: Soul Food (4/5) Movie CLIP - Y'all Messed Up the Family! (1997) HD
# yt_clip_link: https://youtube.com/watch?v=RRcYHJ1uTro
# movie_scene: <subtitle> What are you talking about?
# <subtitle> Supposedly, Mama has some large amount of money stashed someplace in the house that she was saving for Ahmaud.
# <visual descriptions> In the kitchen, Ahmaud dries his hands and listens.
# <subtitle> Ahma...
# subtitles: <subtitle> What are you talking about?
# <subtitle> Supposedly, Mama has some large amount of money stashed someplace in the house that she was saving for Ahmaud.
# <subtitle> Ahmaud!
# <subtitle> Get in here!
# <subtitle> Ahmaud!
# <subtitle> Right now!
# <subt...
# question: What is the predominant color of Ahmaud's attire in the scene?
# choices: ['Black', 'Blue', 'Yellow', 'Red', 'Green']
# answer_key: Black
# answer_key_position: 0
# question_category: Character and
# Relationship Dynamics
#
# --- sample 5 ---
# movie_name: Spontaneous
# year: 2020
# genre: ['Comedy', 'Drama', 'Horror', 'Romance']
# yt_clip_title: Spontaneous (2020) - I Really Wanna Kiss You Scene (3/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=nCT_FTjquzA
# movie_scene: <subtitle> What do you think does?
# <subtitle> Um, I don't know.
# <subtitle> That's not good enough.
# <subtitle> No.
# <subtitle> The cosmic bullshit of the universe, right?
# <subtitle> Lame!
# <subtitle> I'm sorry.
# <visual descriptions> They walk across the...
# subtitles: <subtitle> What do you think does?
# <subtitle> Um, I don't know.
# <subtitle> That's not good enough.
# <subtitle> No.
# <subtitle> The cosmic bullshit of the universe, right?
# <subtitle> Lame!
# <subtitle> I'm sorry.
# <subtitle> I'm writing this book called Al...
# question: How many times does Dylan ask Mara a question?
# choices: ['1', '5', '2', '3', '4']
# answer_key: 2
# answer_key_position: 2
# question_category: Temporal
#
# --- sample 6 ---
# movie_name: Small Soldiers
# year: 1998
# genre: ['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi']
# yt_clip_title: Small Soldiers (3/10) Movie CLIP - Keeper of Encarta (1998) HD
# yt_clip_link: https://youtube.com/watch?v=TgZwFvKRqK4
# movie_scene: <subtitle> Hey!
# <subtitle> What the heck are you?
# <subtitle> You're not like any toy I've ever seen.
# <subtitle> Come on, speak up.
# <subtitle> Greetings, Alan.
# <subtitle> Now shut up.
# <subtitle> I am Archer, emissary of the Gorgonites.
# <subtitle> Mm-h...
# subtitles: <subtitle> Hey!
# <subtitle> What the heck are you?
# <subtitle> You're not like any toy I've ever seen.
# <subtitle> Come on, speak up.
# <subtitle> Greetings, Alan.
# <subtitle> Now shut up.
# <subtitle> I am Archer, emissary of the Gorgonites.
# <subtitle> Mm-h...
# question: Where is Alan in relation to Archer at the end of the scene?
# choices: ['Standing next to him', 'Sitting across from him', 'In front of him', 'Behind him', 'Not present']
# answer_key: In front of him
# answer_key_position: 2
# question_category: Character and
# Relationship Dynamics
#
# --- sample 7 ---
# movie_name: Spider-Man: Into the Spider-Verse
# year: 2018
# genre: ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi']
# yt_clip_title: Spider-Man: Into the Spider-Verse (2018) - Miles vs. Kingpin Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=XMKKYshEbzM
# movie_scene: <subtitle> Not so easy doing it on your own, is it?
# <visual descriptions> Kingpin slams Miles against a window.
# <subtitle> I can't wait to kill one more Spider-Man.
# <visual descriptions> Glitching images of Vanessa and Richard appear.
# <visual descrip...
# subtitles: <subtitle> Not so easy doing it on your own, is it?
# <subtitle> I can't wait to kill one more Spider-Man.
# <subtitle> What?
# <subtitle> Wilson.
# <subtitle> Is this what you want, man?
# <subtitle> What are you doing?
# <subtitle> Stay away from me.
# <subtitle...
# question: What is Kingpin's motive for wanting to kill another Spider-Man?
# choices: ['To assert dominance.', 'To eliminate competition.', 'To seek revenge.', 'To gain power.', 'To protect Vanessa and Richard.']
# answer_key: To seek revenge.
# answer_key_position: 2
# question_category: Narrative and
# Plot Analysis
#
# --- sample 8 ---
# movie_name: Snatch
# year: 2000
# genre: ['Comedy', 'Crime']
# yt_clip_title: The Definition of Nemesis - Snatch (6/8) Movie CLIP (2000) HD
# yt_clip_link: https://youtube.com/watch?v=xu0p6CtioZk
# movie_scene: <subtitle> Well, thank you for that.
# <subtitle> That's a great weight off my mind.
# <subtitle> Now, I mean, if you wouldn't mind telling me who the fuck you are, apart from someone who feeds people to pigs, of course.
# <subtitle> Do you know what nemes...
# subtitles: <subtitle> Well, thank you for that.
# <subtitle> That's a great weight off my mind.
# <subtitle> Now, I mean, if you wouldn't mind telling me who the fuck you are, apart from someone who feeds people to pigs, of course.
# <subtitle> Do you know what nemes...
# question: Which action occurs directly after the nemesis delivers the speech about retribution?
# choices: ['The character says "thank you."', 'The character holds open the door.', 'The character feeds someone to pigs.', 'The character steps over the body.', 'The character says "gentlemen."']
# answer_key: The character steps over the body.
# answer_key_position: 3
# question_category: Temporal
#
# --- sample 9 ---
# movie_name: Smallfoot
# year: 2018
# genre: ['Animation', 'Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Musical']
# yt_clip_title: Smallfoot (2018) - Let It Lie Scene (8/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=kF6apcTT-j8
# movie_scene: <subtitle> You see me, yo.
# <subtitle> There was a time when yetis lived beneath the clouds.
# <subtitle> We were alive and we were thriving till we came across a crowd of smallfoot.
# <subtitle> That's right, we used to live down there.
# <subtitle> But th...
# subtitles: <subtitle> You see me, yo.
# <subtitle> There was a time when yetis lived beneath the clouds.
# <subtitle> We were alive and we were thriving till we came across a crowd of smallfoot.
# <subtitle> That's right, we used to live down there.
# <subtitle> But th...
# question: What is the correct sequence of events in the scene?
# choices: ['Laws were written, humans attacked yetis, and yetis climbed the mountain.', 'Yeti lived beneath the clouds, encountered humans, and climbed the mountain.', 'Humans attacked yetis, laws were written, and yetis climbed the mountain.', 'Yetis climbed ...
# answer_key: Yeti lived beneath the clouds, encountered humans, and climbed the mountain.
# answer_key_position: 1
# question_category: Temporal
#
# -> Sampling split='test' with K=50 (N=4,941, frac=0.01)
# Collected: 50
# No image-like columns detected. Showing text preview:
#
# --- sample 0 ---
# movie_name: Rings
# year: 2017
# genre: ['Drama', 'Horror', 'Mystery', 'Romance']
# yt_clip_title: Rings (2017) - It's Never Over Scene (10/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=pN5RlyFWJBA
# movie_scene: <subtitle> Our souls are eternal.
# <subtitle> And when we die, the spirit strives to find a new home.
# <subtitle> I'm telling you, she's coming back.
# <subtitle> This time for real.
# <subtitle> you were never afraid of.
# <subtitle> Just because you had a ...
# subtitles: <subtitle> Our souls are eternal.
# <subtitle> And when we die, the spirit strives to find a new home.
# <subtitle> I'm telling you, she's coming back.
# <subtitle> This time for real.
# <subtitle> you were never afraid of.
# <subtitle> Just because you had a ...
# question: What is Julia doing when the cicada crawls out?
# choices: ['Standing', 'Lying', 'Leaning', 'Sitting', 'Kneeling']
# answer_key: Leaning
# answer_key_position: 2
# question_category: Setting and
# Technical Analysis
#
# --- sample 1 ---
# movie_name: Delta Farce
# year: 2007
# genre: ['Action', 'Adventure', 'Comedy']
# yt_clip_title: Delta Farce (3/9) Movie CLIP - Butcher of Baghdad (2007) HD
# yt_clip_link: https://youtube.com/watch?v=9_AMztckp6k
# movie_scene: <subtitle> Come on!
# <subtitle> Get some!
# <subtitle> Get some!
# <subtitle> All right, ladies.
# <subtitle> Let's get her done.
# <visual descriptions> The Humvee pulls away, revealing a broken road sign underneath.
# <visual descriptions> Mexico City, 500 ki...
# subtitles: <subtitle> Come on!
# <subtitle> Get some!
# <subtitle> Get some!
# <subtitle> All right, ladies.
# <subtitle> Let's get her done.
# <subtitle> All right, y'all, let's fan out.
# <subtitle> I'll secure the perimeter.
# <subtitle> That Charlie's a real sneaky basta...
# question: Upon arriving at the gas station, which of the following actions does Larry specifically not perform?
# choices: ['He repairs the Humvee.', 'He secures the perimeter.', 'He drives the Humvee.', 'He offers food to the group.', 'He engages in a conversation about securing the perimeter.']
# answer_key: He repairs the Humvee.
# answer_key_position: 0
# question_category: Setting and
# Technical Analysis
#
# --- sample 2 ---
# movie_name: Deuce Bigalow: European Gigolo
# year: 2005
# genre: ['Comedy']
# yt_clip_title: Deuce Bigalow: European Gigolo (2005) - Chicken and Waffles Scene (3/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=-kHMOXNsE2k
# movie_scene: <subtitle> TJ, thank God you're here.
# <subtitle> How'd you find me?
# <subtitle> It's the only chicken and waffle place in all of Holland.
# <subtitle> So a black man's gotta be at a chicken and waffles place.
# <subtitle> That's racist.
# <subtitle> But you...
# subtitles: <subtitle> TJ, thank God you're here.
# <subtitle> How'd you find me?
# <subtitle> It's the only chicken and waffle place in all of Holland.
# <subtitle> So a black man's gotta be at a chicken and waffles place.
# <subtitle> That's racist.
# <subtitle> But you...
# question: How does TJ react when Juice insinuates that his presence at the chicken and waffle place is related to his race?
# choices: ['He laughs it off but in a mocking manner.', 'He expresses genuine anger and outrage.', 'He dismisses it with a nonchalant attitude.', 'He humorously acknowledges the stereotype.', 'He shows signs of sadness and resignation.']
# answer_key: He laughs it off but in a mocking manner.
# answer_key_position: 0
# question_category: Character and
# Relationship Dynamics
#
# --- sample 3 ---
# movie_name: Buddy Games
# year: 2019
# genre: ['Comedy']
# yt_clip_title: Buddy Games (2020) - Man-Juice Pina Coladas Scene (5/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=fslJEzCX2-k
# movie_scene: <subtitle> Can I get you anything?
# <subtitle> Another near beer?
# <subtitle> No, I'm good.
# <subtitle> Okay.
# <subtitle> You know what, though?
# <subtitle> I'm gonna get you something.
# <subtitle> Okay.
# <subtitle> Show you how I feel about everything.
# <su...
# subtitles: <subtitle> Can I get you anything?
# <subtitle> Another near beer?
# <subtitle> No, I'm good.
# <subtitle> Okay.
# <subtitle> You know what, though?
# <subtitle> I'm gonna get you something.
# <subtitle> Okay.
# <subtitle> Show you how I feel about everything.
# <su...
# question: What is the setting where the guys hang out?
# choices: ['Living room', 'Bedroom', 'Fireplace', 'Kitchen', 'Bathroom']
# answer_key: Fireplace
# answer_key_position: 2
# question_category: Setting and
# Technical Analysis
#
# --- sample 4 ---
# movie_name: Barb Wire
# year: 1996
# genre: ['Action', 'Sci-Fi']
# yt_clip_title: Barb Wire (5/10) Movie CLIP - Package Check (1996) HD
# yt_clip_link: https://youtube.com/watch?v=n9L9jMlulXI
# movie_scene: <subtitle> You, you, or you!
# <subtitle> Just give me my drink!
# <subtitle> Sir, we're not open yet.
# <subtitle> I think you've had enough already.
# <subtitle> Ah, blow me.
# <subtitle> Camille, package check.
# <visual descriptions> Camille runs up and bite...
# subtitles: <subtitle> You, you, or you!
# <subtitle> Just give me my drink!
# <subtitle> Sir, we're not open yet.
# <subtitle> I think you've had enough already.
# <subtitle> Ah, blow me.
# <subtitle> Camille, package check.
# <subtitle> Get her off!
# <subtitle> Get her off...
# question: How does the conflict between the man and the staff unfold?
# choices: ['The man is given a warning', 'The man is asked to leave politely', 'The man is bitten and dragged out', 'The man is ignored by the staff', 'The man is served a drink']
# answer_key: The man is bitten and dragged out
# answer_key_position: 2
# question_category: Narrative and
# Plot Analysis
#
# --- sample 5 ---
# movie_name: Ouija
# year: 2014
# genre: ['Horror', 'Mystery', 'Thriller']
# yt_clip_title: Ouija (7/10) Movie CLIP - We Shouldn't Be Here (2014) HD
# yt_clip_link: https://youtube.com/watch?v=CDiosBMzR_c
# movie_scene: <subtitle> We should just leave.
# <subtitle> We shouldn't be here.
# <subtitle> What?
# <subtitle> The shadow?
# <visual descriptions> The shadow attacks Trevor.
# <visual descriptions> A force drags Trevor through a doorway into a dark room, then slams him i...
# subtitles: <subtitle> We should just leave.
# <subtitle> We shouldn't be here.
# <subtitle> What?
# <subtitle> The shadow?
# <subtitle> Trevor!
# <subtitle> Pete!
# <subtitle> Trevor!
# <subtitle> Pete!
# <subtitle> Lane!
# <subtitle> Keep going!
# <subtitle> Sarah, I need your he...
# question: How does the discovery of the mummified corpse impact the characters?
# choices: ['It leads them to a hidden treasure', 'It reveals a coded message', 'It provides a magical artifact', 'It triggers a trap', 'It frightens them']
# answer_key: It frightens them
# answer_key_position: 4
# question_category: Narrative and
# Plot Analysis
#
# --- sample 6 ---
# movie_name: Ouija
# year: 2014
# genre: ['Horror', 'Mystery', 'Thriller']
# yt_clip_title: Ouija (9/10) Movie CLIP - You Have to Play (2014) HD
# yt_clip_link: https://youtube.com/watch?v=m3262E3sfb8
# movie_scene: <subtitle> Let's burn this damn thing already.
# <visual descriptions> Sarah gets dragged through the small wall opening.
# <subtitle> Sarah!
# <subtitle> Sarah!
# <visual descriptions> In the dark chamber, candles light spontaneously.
# <visual descriptions> ...
# subtitles: <subtitle> Let's burn this damn thing already.
# <subtitle> Sarah!
# <subtitle> Sarah!
# <subtitle> As friends we've gathered, hearts are true.
# <subtitle> Spirit's near, we call to you.
# <subtitle> Doris, I'm playing alone, you have to play!
# <subtitle> Dori...
# question: In the climactic sequence, what immediate effect does Sarah's action of throwing the bundle into the furnace have on the surroundings and characters?
# choices: ["A shockwave emanates from the furnace, causing Sarah to be thrown back, while black smoke pours from Doris' mouth.", 'The furnace erupts into flames, leading the spirits to become more aggressive and chaotic.', 'Sarah is paralyzed by a shockwave, b...
# answer_key: A shockwave emanates from the furnace, causing Sarah to be thrown back, while black smoke pours from Doris' mouth.
# answer_key_position: 0
# question_category: Narrative and
# Plot Analysis
#
# --- sample 7 ---
# movie_name: Jack and Jill
# year: 2011
# genre: ['Comedy']
# yt_clip_title: Jack and Jill (2011) - Felipe's Family Scene (4/6) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=sk82NsHwkts
# movie_scene: <subtitle> This is my friend Jill.
# <subtitle> That's my father, my mama, my brother Juan, my other brother Juan, Juan Jr., my sister Juanita, my grandma Juangelina, and that... I'm kidding!
# <subtitle> I was gonna say, that's a lot of Juan!
# <subtitle>...
# subtitles: <subtitle> This is my friend Jill.
# <subtitle> That's my father, my mama, my brother Juan, my other brother Juan, Juan Jr., my sister Juanita, my grandma Juangelina, and that... I'm kidding!
# <subtitle> I was gonna say, that's a lot of Juan!
# <subtitle>...
# question: What action does Jill perform to entertain the crowd?
# choices: ['Does a dance', 'Plays an instrument', 'Reads a poem', 'Sings a song', 'Tells a joke']
# answer_key: Does a dance
# answer_key_position: 0
# question_category: Setting and
# Technical Analysis
#
# --- sample 8 ---
# movie_name: Cats & Dogs: The Revenge of Kitty Galore
# year: 2010
# genre: ['Action', 'Comedy', 'Family', 'Fantasy']
# yt_clip_title: Cats & Dogs: The Revenge of Kitty Galore #7 Movie CLIP - I Think I Like You (2010) HD
# yt_clip_link: https://youtube.com/watch?v=a88BNDMlPSE
# movie_scene: <subtitle> There's got to be a way out of here.
# <subtitle> Catherine, listen.
# <subtitle> Since this is the end, I guess I can say I think I might like you.
# <subtitle> Dig, stop.
# <subtitle> No, don't say anything.
# <subtitle> I know it's uncomfortable ...
# subtitles: <subtitle> There's got to be a way out of here.
# <subtitle> Catherine, listen.
# <subtitle> Since this is the end, I guess I can say I think I might like you.
# <subtitle> Dig, stop.
# <subtitle> No, don't say anything.
# <subtitle> I know it's uncomfortable ...
# question: What is the primary plan of escape for the characters in the scene?
# choices: ['Fighting their way out', 'Using a secret door', 'Waiting for rescue', 'Calling for help', 'Using a collar to pick a lock']
# answer_key: Using a collar to pick a lock
# answer_key_position: 4
# question_category: Character and
# Relationship Dynamics
#
# --- sample 9 ---
# movie_name: Daddy Day Camp
# year: 2007
# genre: ['Comedy', 'Family']
# yt_clip_title: Daddy Day Camp (2007) - Rock Wall Climb Scene (10/10) | Movieclips
# yt_clip_link: https://youtube.com/watch?v=NN0GuXudBL8
# movie_scene: <subtitle> It's okay.
# <subtitle> It's okay, son.
# <subtitle> I told you, you're a loser, just like your old man.
# <subtitle> You're not a loser, Ben!
# <subtitle> He greased the wall!
# <subtitle> He's cheating!
# <subtitle> No, don't listen to her!
# <subtitl...
# subtitles: <subtitle> It's okay.
# <subtitle> It's okay, son.
# <subtitle> I told you, you're a loser, just like your old man.
# <subtitle> You're not a loser, Ben!
# <subtitle> He greased the wall!
# <subtitle> He's cheating!
# <subtitle> No, don't listen to her!
# <subtitl...
# question: What action does Ben take after sprinting to the tree?
# choices: ['Jumps', 'Hides', 'Calls for help', 'Rests', 'Climbs']
# answer_key: Climbs
# answer_key_position: 4
# question_category: Setting and
# Technical Analysis

# %%
from datasets import load_dataset

cfg, split = "v2", "train"
ds = load_dataset("tomg-group-umd/cinepile", cfg, split=split, streaming=True)

ex = next(iter(ds))
print("keys:", list(ex.keys()))

# look for anything video-ish
videoish = [k for k in ex.keys() if "video" in k.lower() or "mp4" in k.lower() or "path" in k.lower()]
print("video-ish keys:", videoish)

# also check if any value is a dict with bytes/path (typical HF media)
media_like = [k for k,v in ex.items() if isinstance(v, dict) and ("bytes" in v or "path" in v)]
print("media-like dict fields:", media_like)
# Out:
# keys: ['movie_name', 'year', 'genre', 'yt_clip_title', 'yt_clip_link', 'movie_scene', 'subtitles', 'question', 'choices', 'answer_key', 'answer_key_position', 'question_category', 'hard_split', 'visual_reliance', 'videoID']
# video-ish keys: ['videoID']
# media-like dict fields: []
