# %%
import sys, os, site
print("sys.executable:", sys.executable)
print("CONDA_PREFIX:", os.environ.get("CONDA_PREFIX"))
print("site-packages:", site.getsitepackages()[:2])
# Out:
# sys.executable: /ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/bin/python
# CONDA_PREFIX: /sw/rl9g/machine_learning/2024.01/rl9_cudnn8_cuda11.8_py3.9_env/machine_learning-module/env
# site-packages: ['/ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/lib/python3.10/site-packages']

# %%
import os, sys
from pathlib import Path

ENV_BIN = str(Path(sys.executable).resolve().parent)  # .../envs/oxe/bin
os.environ["PATH"] = ENV_BIN + ":" + os.environ.get("PATH", "")

print("ENV_BIN:", ENV_BIN)
print("gsutil which:", os.popen("which gsutil").read().strip())
# Out:
# ENV_BIN: /ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/bin
# gsutil which: /ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/bin/gsutil

# %%
import shutil, subprocess, os

print("which gsutil:", shutil.which("gsutil"))
print("PATH:", os.environ.get("PATH","")[:200], "...")
subprocess.run("gsutil version", shell=True)
# Out:
# which gsutil: /ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/bin/gsutil
# PATH: /ibex/project/c2320/dataset-check/x-embodiment/envs/oxe/bin:/sw/rl9g/machine_learning/2024.01/rl9_cudnn8_cuda11.8_py3.9_env/machine_learning-module/env/bin:/sw/rl9g/cuda/11.8/rl9_binary/bin:/sw/rl9g/g ...
# gsutil version: 5.35
# CompletedProcess(args='gsutil version', returncode=0)

# %%
import json, re, subprocess
from pathlib import Path
from datetime import datetime

import pandas as pd

# === Where to save outputs ===
OUT_DIR = Path.cwd() / "oxe_peek"
SCAN_DIR = OUT_DIR / "features_scan"
OUT_DIR.mkdir(parents=True, exist_ok=True)
SCAN_DIR.mkdir(parents=True, exist_ok=True)

# === Buckets to try (order matters) ===
BUCKETS = [
    "gs://gdm-robotics-open-x-embodiment",
    "gs://gresearch/robotics",
]

print("OUT_DIR:", OUT_DIR)
print("SCAN_DIR:", SCAN_DIR)
print("Buckets:", BUCKETS)
# Out:
# OUT_DIR: /ibex/project/c2320/dataset-check/x-embodiment/oxe_peek
# SCAN_DIR: /ibex/project/c2320/dataset-check/x-embodiment/oxe_peek/features_scan
# Buckets: ['gs://gdm-robotics-open-x-embodiment', 'gs://gresearch/robotics']

# %%
import subprocess, time, shutil

def gsutil(cmd: str, timeout_s: int = 60) -> str:
    """
    Run gsutil with a timeout so one dataset can't hang forever.
    """
    if shutil.which("gsutil") is None:
        raise RuntimeError("gsutil not found in PATH inside this kernel")

    p = subprocess.run(
        cmd,
        shell=True,
        text=True,
        capture_output=True,
        timeout=timeout_s,
    )
    if p.returncode != 0:
        raise RuntimeError(
            f"gsutil failed ({p.returncode})\n"
            f"CMD: {cmd}\nSTDOUT:\n{p.stdout}\nSTDERR:\n{p.stderr}"
        )
    return p.stdout

# %%
def list_versions(ds: str):
    """
    List semver-like version folders for a dataset, trying both buckets.
    Returns (versions, bucket_used).
    """
    last_err = None

    for base in BUCKETS:
        try:
            out = gsutil(f'gsutil ls "{base}/{ds}/"')
            lines = [ln.strip() for ln in out.splitlines() if ln.strip().startswith("gs://")]

            vers = []
            for ln in lines:
                name = ln.rstrip("/").split("/")[-1]
                name = name.replace("_$folder$", "").replace(":", "")
                if re.match(r"^\d+\.\d+\.\d+$", name):
                    vers.append(name)

            def semver_key(s): 
                return tuple(int(x) for x in s.split("."))

            vers = sorted(set(vers), key=semver_key)
            return vers, base

        except Exception as e:
            last_err = e

    # nothing worked
    raise last_err


def load_features_json(ds: str, version: str, out_dir: Path):
    """
    Download features.json, trying both buckets.
    Returns (features_dict, local_path, gcs_path_used).
    """
    out_dir.mkdir(parents=True, exist_ok=True)
    local = out_dir / f"{ds}__{version}__features.json"

    last_err = None
    for base in BUCKETS:
        gcs = f'{base}/{ds}/{version}/features.json'
        try:
            # existence check first (gives clearer errors)
            gsutil(f'gsutil ls "{gcs}"')
            gsutil(f'gsutil cp "{gcs}" "{local}"')
            return json.loads(local.read_text()), local, gcs
        except Exception as e:
            last_err = e

    raise last_err

# %%
def find_image_descriptions(feats):
    # find any "description" fields near "image" features
    descs = []
    def rec(o, path=""):
        if isinstance(o, dict):
            for k, v in o.items():
                rec(v, f"{path}/{k}")
        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")
        else:
            if isinstance(o, str) and "description" in path and re.search(r"(image|rgb|camera|wrist|front|left|right)", path, re.I):
                descs.append((path, o))
    rec(feats)
    return descs

def has_real_rgb(desc_text: str):
    # heuristic: placeholder datasets explicitly say not available / zeros
    bad = ["not available", "np.zeros", "zeros"]
    return not any(b in desc_text.lower() for b in bad)

# %%
# Paste your dataset names here (one per line)
CANDIDATES_TEXT = """
language_table
stanford_hydra_dataset_converted_externally_to_rlds
austin_buds_dataset_converted_externally_to_rlds
furniture_bench_dataset_converted_externally_to_rlds
cmu_franka_exploration_dataset_converted_externally_to_rlds
ucsd_kitchen_dataset_converted_externally_to_rlds
austin_sirius_dataset_converted_externally_to_rlds
utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds
utokyo_saytap_converted_externally_to_rlds
berkeley_mvp_converted_externally_to_rlds
kaist_nonprehensile_converted_externally_to_rlds
dlr_sara_pour_converted_externally_to_rlds
asu_table_top_converted_externally_to_rlds
stanford_robocook_converted_externally_to_rlds
iamlab_cmu_pickup_insert_converted_externally_to_rlds
utaustin_mutex
berkeley_fanuc_manipulation
cmu_playing_with_food
cmu_stretch
berkeley_gnm_cory_hall
berkeley_gnm_sac_son
eth_agent_affordances
kuka
columbia_cairlab_pusht_real
robot_vqa
fractal20220817_data
bridge
taco_play
jaco_play
berkeley_cable_routing
roboturk
nyu_door_opening_surprising_effectiveness
viola
berkeley_autolab_ur5
toto
stanford_kuka_multimodal_dataset_converted_externally_to_rlds
nyu_rot_dataset_converted_externally_to_rlds
nyu_franka_play_dataset_converted_externally_to_rlds
maniskill_dataset_converted_externally_to_rlds
ucsd_pick_and_place_dataset_converted_externally_to_rlds
austin_sailor_dataset_converted_externally_to_rlds
bc_z
usc_cloth_sim_converted_externally_to_rlds
utokyo_pr2_opening_fridge_converted_externally_to_rlds
utokyo_xarm_pick_and_place_converted_externally_to_rlds
utokyo_xarm_bimanual_converted_externally_to_rlds
robo_net
berkeley_rpt_converted_externally_to_rlds
stanford_mask_vit_converted_externally_to_rlds
tokyo_u_lsmo_converted_externally_to_rlds
dlr_sara_grid_clamp_converted_externally_to_rlds
dlr_edan_shared_control_converted_externally_to_rlds
imperialcollege_sawyer_wrist_cam
qut_dexterous_manipulation
uiuc_d3field
cmu_play_fusion
berkeley_gnm_recon
droid
conq_hose_manipulation
dobbe
fmb
io_ai_tech
mimic_play
aloha_mobile
robo_set
tidybot
vima_converted_externally_to_rlds
spoc
plex_robosuite
""".strip()

CANDIDATES = [x.strip() for x in CANDIDATES_TEXT.splitlines() if x.strip()]
print("Candidates:", len(CANDIDATES))
print(CANDIDATES[:10])
# Out:
# Candidates: 69
# ['language_table', 'stanford_hydra_dataset_converted_externally_to_rlds', 'austin_buds_dataset_converted_externally_to_rlds', 'furniture_bench_dataset_converted_externally_to_rlds', 'cmu_franka_exploration_dataset_converted_externally_to_rlds', 'ucsd_kitchen_dataset_converted_externally_to_rlds', 'austin_sirius_dataset_converted_externally_to_rlds', 'utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds', 'utokyo_saytap_converted_externally_to_rlds', 'berkeley_mvp_converted_externally_to_rlds']

# %%
results = []

for ds in CANDIDATES:
    try:
        vers, bucket_for_versions = list_versions(ds)
        if not vers:
            results.append({
                "dataset": ds,
                "version": None,
                "rgb_real": False,
                "note": "no version folders found",
                "bucket_versions": bucket_for_versions,
                "bucket_features": None,
            })
            continue

        v = vers[-1]  # latest semver

        feats, local_path, gcs_path = load_features_json(ds, v, SCAN_DIR)
        descs = find_image_descriptions(feats)

        if not descs:
            results.append({
                "dataset": ds,
                "version": v,
                "rgb_real": None,
                "note": f"features.json downloaded ({local_path.name}) from {gcs_path} but no image description hits",
                "bucket_versions": bucket_for_versions,
                "bucket_features": gcs_path.split("/", 3)[0] + "//" + gcs_path.split("/", 3)[2],  # rough bucket id
            })
            continue

        real_any = any(has_real_rgb(desc) for _, desc in descs)
        rep = descs[0][1].replace("\n", " ")[:200]

        results.append({
            "dataset": ds,
            "version": v,
            "rgb_real": bool(real_any),
            "note": rep,
            "bucket_versions": bucket_for_versions,
            "bucket_features": gcs_path.split("/", 3)[0] + "//" + gcs_path.split("/", 3)[2],
        })

    except Exception as e:
        results.append({
            "dataset": ds,
            "version": None,
            "rgb_real": False,
            "note": f"error: {e}",
            "bucket_versions": None,
            "bucket_features": None,
        })

df = pd.DataFrame(results)
df
# Out:
#                                               dataset version rgb_real  \
# 0                                      language_table   0.1.0     True
# 1   stanford_hydra_dataset_converted_externally_to...   0.1.0     True
# 2    austin_buds_dataset_converted_externally_to_rlds   0.1.0     True
# 3   furniture_bench_dataset_converted_externally_t...   0.1.0     True
# 4   cmu_franka_exploration_dataset_converted_exter...   0.1.0     True
# ..                                                ...     ...      ...
# 64                                           robo_set   0.0.1     None
# 65                                            tidybot   0.0.1     None
# 66                  vima_converted_externally_to_rlds   0.0.1     None
# 67                                               spoc   0.0.1     None
# 68                                     plex_robosuite   0.0.1     None
#
#                                                  note  \
# 0                          An RGB image of the scene.
# 1                        Main camera RGB observation.
# 2                        Main camera RGB observation.
# 3                        Main camera RGB observation.
# 4                        Main camera RGB observation.
# ..                                                ...
# 64  features.json downloaded (robo_set__0.0.1__fea...
# 65  features.json downloaded (tidybot__0.0.1__feat...
# 66  features.json downloaded (vima_converted_exter...
# 67  features.json downloaded (spoc__0.0.1__feature...
# 68  features.json downloaded (plex_robosuite__0.0....
#
#                         bucket_versions                      bucket_features
# 0   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 1   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 2   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 3   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 4   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# ..                                  ...                                  ...
# 64              gs://gresearch/robotics                       gs://gresearch
# 65              gs://gresearch/robotics                       gs://gresearch
# 66              gs://gresearch/robotics                       gs://gresearch
# 67              gs://gresearch/robotics                       gs://gresearch
# 68              gs://gresearch/robotics                       gs://gresearch
#
# [69 rows x 6 columns]

# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)   # show full text in "note"
df
# Out:
#                                                           dataset version  \
# 0                                                  language_table   0.1.0
# 1             stanford_hydra_dataset_converted_externally_to_rlds   0.1.0
# 2                austin_buds_dataset_converted_externally_to_rlds   0.1.0
# 3            furniture_bench_dataset_converted_externally_to_rlds   0.1.0
# 4     cmu_franka_exploration_dataset_converted_externally_to_rlds   0.1.0
# 5               ucsd_kitchen_dataset_converted_externally_to_rlds   0.1.0
# 6              austin_sirius_dataset_converted_externally_to_rlds   0.1.0
# 7   utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds   1.0.0
# 8                      utokyo_saytap_converted_externally_to_rlds   0.1.0
# 9                       berkeley_mvp_converted_externally_to_rlds   0.1.0
# 10               kaist_nonprehensile_converted_externally_to_rlds   0.1.0
# 11                     dlr_sara_pour_converted_externally_to_rlds   0.1.0
# 12                     asu_table_top_converted_externally_to_rlds   0.1.0
# 13                 stanford_robocook_converted_externally_to_rlds   0.1.0
# 14          iamlab_cmu_pickup_insert_converted_externally_to_rlds   0.1.0
# 15                                                 utaustin_mutex   0.1.0
# 16                                    berkeley_fanuc_manipulation   0.1.0
# 17                                          cmu_playing_with_food   1.0.0
# 18                                                    cmu_stretch   0.1.0
# 19                                         berkeley_gnm_cory_hall   0.1.0
# 20                                           berkeley_gnm_sac_son   0.1.0
# 21                                          eth_agent_affordances   0.1.0
# 22                                                           kuka   0.1.0
# 23                                    columbia_cairlab_pusht_real   0.1.0
# 24                                                      robot_vqa   0.1.0
# 25                                           fractal20220817_data   0.1.0
# 26                                                         bridge   0.1.0
# 27                                                      taco_play   0.1.0
# 28                                                      jaco_play   0.1.0
# 29                                         berkeley_cable_routing   0.1.0
# 30                                                       roboturk   0.1.0
# 31                      nyu_door_opening_surprising_effectiveness   0.1.0
# 32                                                          viola   0.1.0
# 33                                           berkeley_autolab_ur5   0.1.0
# 34                                                           toto   0.1.0
# 35  stanford_kuka_multimodal_dataset_converted_externally_to_rlds   0.1.0
# 36                   nyu_rot_dataset_converted_externally_to_rlds   0.1.0
# 37           nyu_franka_play_dataset_converted_externally_to_rlds   0.1.0
# 38                 maniskill_dataset_converted_externally_to_rlds   0.1.0
# 39       ucsd_pick_and_place_dataset_converted_externally_to_rlds   0.1.0
# 40             austin_sailor_dataset_converted_externally_to_rlds   0.1.0
# 41                                                           bc_z   1.0.1
# 42                     usc_cloth_sim_converted_externally_to_rlds   0.1.0
# 43         utokyo_pr2_opening_fridge_converted_externally_to_rlds   0.1.0
# 44        utokyo_xarm_pick_and_place_converted_externally_to_rlds   0.1.0
# 45              utokyo_xarm_bimanual_converted_externally_to_rlds   0.1.0
# 46                                                       robo_net   1.0.0
# 47                      berkeley_rpt_converted_externally_to_rlds   0.1.0
# 48                 stanford_mask_vit_converted_externally_to_rlds   0.1.0
# 49                      tokyo_u_lsmo_converted_externally_to_rlds   0.1.0
# 50               dlr_sara_grid_clamp_converted_externally_to_rlds   0.1.0
# 51           dlr_edan_shared_control_converted_externally_to_rlds   0.1.0
# 52                               imperialcollege_sawyer_wrist_cam   0.1.0
# 53                                     qut_dexterous_manipulation    None
# 54                                                   uiuc_d3field   1.1.2
# 55                                                cmu_play_fusion   0.1.0
# 56                                             berkeley_gnm_recon   0.1.0
# 57                                                          droid   1.0.1
# 58                                         conq_hose_manipulation   0.0.1
# 59                                                          dobbe   0.0.1
# 60                                                            fmb   0.0.1
# 61                                                     io_ai_tech   0.0.1
# 62                                                     mimic_play   0.0.1
# 63                                                   aloha_mobile   0.0.1
# 64                                                       robo_set   0.0.1
# 65                                                        tidybot   0.0.1
# 66                              vima_converted_externally_to_rlds   0.0.1
# 67                                                           spoc   0.0.1
# 68                                                 plex_robosuite   0.0.1
#
#    rgb_real  \
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     True
# 28     None
# 29     None
# 30     None
# 31     None
# 32     True
# 33     None
# 34     None
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53    False
# 54     True
# 55     True
# 56     True
# 57     None
# 58     None
# 59     None
# 60     None
# 61     None
# 62     None
# 63     None
# 64     None
# 65     None
# 66     None
# 67     None
# 68     None
#
#                                                                                                                                                                                                                    note  \
# 0                                                                                                                                                                                            An RGB image of the scene.
# 1                                                                                                                                                                                          Main camera RGB observation.
# 2                                                                                                                                                                                          Main camera RGB observation.
# 3                                                                                                                                                                                          Main camera RGB observation.
# 4                                                                                                                                                                                          Main camera RGB observation.
# 5                                                                                                                                                                                          Main camera RGB observation.
# 6                                                                                                                                                                                         Wrist camera RGB observation.
# 7                                                                                                                                                                                          Main camera RGB observation.
# 8                                                                                                                                                                                   Dummy wrist camera RGB observation.
# 9                                                                                                                                                                                          Hand camera RGB observation.
# 10                                                                                                                                                                                         Main camera RGB observation.
# 11                                                                                                                                                                                         Main camera RGB observation.
# 12                                                                                                                                                                                         Main camera RGB observation.
# 13                                                                                                                                                                                            Camera 1 RGB observation.
# 14                                                                                                                                                                                        Wrist camera RGB observation.
# 15                                                                                                                                                                                        Wrist camera RGB observation.
# 16                                                                                                                                                                                         Main camera RGB observation.
# 17                                                                                                                                                                                         Main camera RGB observation.
# 18                                                                                                                                                                                         Main camera RGB observation.
# 19                                                                                                                                                                                         Main camera RGB observation.
# 20                                                                                                                                                                                         Main camera RGB observation.
# 21                                                                                                                                Main camera RGB observation. Not available for this dataset, will be set to np.zeros.
# 22                                                                features.json downloaded (kuka__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/kuka/0.1.0/features.json but no image description hits
# 23                  features.json downloaded (columbia_cairlab_pusht_real__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/columbia_cairlab_pusht_real/0.1.0/features.json but no image description hits
# 24                                                      features.json downloaded (robot_vqa__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/robot_vqa/0.1.0/features.json but no image description hits
# 25                                            features.json downloaded (fractal20220817_data__0.1.0__features.json) from gs://gresearch/robotics/fractal20220817_data/0.1.0/features.json but no image description hits
# 26                                                                        features.json downloaded (bridge__0.1.0__features.json) from gs://gresearch/robotics/bridge/0.1.0/features.json but no image description hits
# 27                                                                                                                                        RGB static image of shape. (150, 200, 3). Subsampled from (200,200, 3) image.
# 28                                                                  features.json downloaded (jaco_play__0.1.0__features.json) from gs://gresearch/robotics/jaco_play/0.1.0/features.json but no image description hits
# 29                                        features.json downloaded (berkeley_cable_routing__0.1.0__features.json) from gs://gresearch/robotics/berkeley_cable_routing/0.1.0/features.json but no image description hits
# 30                                                                    features.json downloaded (roboturk__0.1.0__features.json) from gs://gresearch/robotics/roboturk/0.1.0/features.json but no image description hits
# 31  features.json downloaded (nyu_door_opening_surprising_effectiveness__0.1.0__features.json) from gs://gresearch/robotics/nyu_door_opening_surprising_effectiveness/0.1.0/features.json but no image description hits
# 32                                                                                                                                                                                     RGB captured by workspace camera
# 33                                            features.json downloaded (berkeley_autolab_ur5__0.1.0__features.json) from gs://gresearch/robotics/berkeley_autolab_ur5/0.1.0/features.json but no image description hits
# 34                                                                            features.json downloaded (toto__0.1.0__features.json) from gs://gresearch/robotics/toto/0.1.0/features.json but no image description hits
# 35                                                                                                                                                                                       Main depth camera observation.
# 36                                                                                                                                                                                         Main camera RGB observation.
# 37                                                                                                                                                                                        Right camera RGB observation.
# 38                                                                                                                                                                                         Main camera RGB observation.
# 39                                                                                                                                                                                              Camera RGB observation.
# 40                                                                                                                                                                                         Main camera RGB observation.
# 41                                                                                                                                                                            Camera image of the robot, downsampled 3x
# 42                                                                                                                                                                                          Image observation of cloth.
# 43                                                                                                                                                                                         Main camera RGB observation.
# 44                                                                                                                                                                                         Main camera RGB observation.
# 45                                                                                                                                                                                         Main camera RGB observation.
# 46                                                                                                                                                                                         Main camera RGB observation.
# 47                                                                                                                                                                                         Hand camera RGB observation.
# 48                                                                                                                                                                                         Main camera RGB observation.
# 49                                                                                                                                                                                         Main camera RGB observation.
# 50                                                                                                                                                                                         Main camera RGB observation.
# 51                                                                                                                                                                                         Main camera RGB observation.
# 52                                                                                                                                                                                        Wrist camera RGB observation.
# 53                                         error: gsutil failed (1)\nCMD: gsutil ls "gs://gresearch/robotics/qut_dexterous_manipulation/"\nSTDOUT:\n\nSTDERR:\nCommandException: One or more URLs matched no objects.\n
# 54                                                                                                                                                                                            camera 1 RGB observation.
# 55                                                                                                                                                                                         Main camera RGB observation.
# 56                                                                                                                                                                                         Main camera RGB observation.
# 57                                                                          features.json downloaded (droid__1.0.1__features.json) from gs://gresearch/robotics/droid/1.0.1/features.json but no image description hits
# 58                                        features.json downloaded (conq_hose_manipulation__0.0.1__features.json) from gs://gresearch/robotics/conq_hose_manipulation/0.0.1/features.json but no image description hits
# 59                                                                          features.json downloaded (dobbe__0.0.1__features.json) from gs://gresearch/robotics/dobbe/0.0.1/features.json but no image description hits
# 60                                                                              features.json downloaded (fmb__0.0.1__features.json) from gs://gresearch/robotics/fmb/0.0.1/features.json but no image description hits
# 61                                                                features.json downloaded (io_ai_tech__0.0.1__features.json) from gs://gresearch/robotics/io_ai_tech/0.0.1/features.json but no image description hits
# 62                                                                features.json downloaded (mimic_play__0.0.1__features.json) from gs://gresearch/robotics/mimic_play/0.0.1/features.json but no image description hits
# 63                                                            features.json downloaded (aloha_mobile__0.0.1__features.json) from gs://gresearch/robotics/aloha_mobile/0.0.1/features.json but no image description hits
# 64                                                                    features.json downloaded (robo_set__0.0.1__features.json) from gs://gresearch/robotics/robo_set/0.0.1/features.json but no image description hits
# 65                                                                      features.json downloaded (tidybot__0.0.1__features.json) from gs://gresearch/robotics/tidybot/0.0.1/features.json but no image description hits
# 66                  features.json downloaded (vima_converted_externally_to_rlds__0.0.1__features.json) from gs://gresearch/robotics/vima_converted_externally_to_rlds/0.0.1/features.json but no image description hits
# 67                                                                            features.json downloaded (spoc__0.0.1__features.json) from gs://gresearch/robotics/spoc/0.0.1/features.json but no image description hits
# 68                                                        features.json downloaded (plex_robosuite__0.0.1__features.json) from gs://gresearch/robotics/plex_robosuite/0.0.1/features.json but no image description hits
#
#                         bucket_versions                      bucket_features
# 0   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 1   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 2   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 3   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 4   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 5   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 6   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 7   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 8   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 9   gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 10  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 11  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 12  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 13  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 14  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 15  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 16  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 17  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 18  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 19  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 20  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 21  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 22  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 23  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 24  gs://gdm-robotics-open-x-embodiment  gs://gdm-robotics-open-x-embodiment
# 25  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 26  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 27  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 28  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 29  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 30  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 31  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 32  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 33  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 34  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 35  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 36  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 37  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 38  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 39  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 40  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 41  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 42  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 43  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 44  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 45  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 46  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 47  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 48  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 49  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 50  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 51  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 52  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 53                                 None                                 None
# 54  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 55  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 56  gs://gdm-robotics-open-x-embodiment                       gs://gresearch
# 57              gs://gresearch/robotics                       gs://gresearch
# 58              gs://gresearch/robotics                       gs://gresearch
# 59              gs://gresearch/robotics                       gs://gresearch
# 60              gs://gresearch/robotics                       gs://gresearch
# 61              gs://gresearch/robotics                       gs://gresearch
# 62              gs://gresearch/robotics                       gs://gresearch
# 63              gs://gresearch/robotics                       gs://gresearch
# 64              gs://gresearch/robotics                       gs://gresearch
# 65              gs://gresearch/robotics                       gs://gresearch
# 66              gs://gresearch/robotics                       gs://gresearch
# 67              gs://gresearch/robotics                       gs://gresearch
# 68              gs://gresearch/robotics                       gs://gresearch

# %%
def find_image_specs(feats):
    hits = []

    def rec(o, path=""):
        if isinstance(o, dict):
            shape = o.get("shape")
            dtype = o.get("dtype")

            if isinstance(shape, (list, tuple)) and len(shape) in (3, 4):
                c = shape[-1]
                if c in (1, 3, 4):
                    hits.append({
                        "path": path,
                        "shape": shape,
                        "dtype": dtype,
                        "keys": list(o.keys())
                    })

            for k, v in o.items():
                rec(v, f"{path}/{k}")

        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")

    rec(feats)
    return hits

# %%
from pathlib import Path
import json
import pandas as pd

unknown_df = df[df["rgb_real"].isna()].copy()
print("Datasets with unknown RGB:", len(unknown_df))
# Out:
# Datasets with unknown RGB: 23

# %%
spec_results = []

for _, row in unknown_df.iterrows():
    ds = row["dataset"]
    v  = row["version"]

    feats_path = SCAN_DIR / f"{ds}__{v}__features.json"

    if not feats_path.exists():
        spec_results.append({
            "dataset": ds,
            "version": v,
            "spec_hits": 0,
            "spec_paths": None,
            "note": "features.json missing"
        })
        continue

    feats = json.loads(feats_path.read_text())
    hits = find_image_specs(feats)

    spec_results.append({
        "dataset": ds,
        "version": v,
        "spec_hits": len(hits),
        "spec_paths": [h["path"] for h in hits[:5]] if hits else None
    })

# %%
spec_df = pd.DataFrame(spec_results)
display(spec_df)
# Out:
#                                       dataset version  spec_hits spec_paths
# 0                                        kuka   0.1.0          0       None
# 1                 columbia_cairlab_pusht_real   0.1.0          0       None
# 2                                   robot_vqa   0.1.0          0       None
# 3                        fractal20220817_data   0.1.0          0       None
# 4                                      bridge   0.1.0          0       None
# 5                                   jaco_play   0.1.0          0       None
# 6                      berkeley_cable_routing   0.1.0          0       None
# 7                                    roboturk   0.1.0          0       None
# 8   nyu_door_opening_surprising_effectiveness   0.1.0          0       None
# 9                        berkeley_autolab_ur5   0.1.0          0       None
# 10                                       toto   0.1.0          0       None
# 11                                      droid   1.0.1          0       None
# 12                     conq_hose_manipulation   0.0.1          0       None
# 13                                      dobbe   0.0.1          0       None
# 14                                        fmb   0.0.1          0       None
# 15                                 io_ai_tech   0.0.1          0       None
# 16                                 mimic_play   0.0.1          0       None
# 17                               aloha_mobile   0.0.1          0       None
# 18                                   robo_set   0.0.1          0       None
# 19                                    tidybot   0.0.1          0       None
# 20          vima_converted_externally_to_rlds   0.0.1          0       None
# 21                                       spoc   0.0.1          0       None
# 22                             plex_robosuite   0.0.1          0       None

# %%
def find_image_keys_only(feats):
    keys = []
    def rec(o, path=""):
        if isinstance(o, dict):
            for k, v in o.items():
                p = f"{path}/{k}"
                if re.search(r"(rgb|image|camera|wrist|front|left|right)", p, re.I):
                    keys.append(p)
                rec(v, p)
        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")
    rec(feats)
    return keys

# %%
ds = "plex_robosuite"
v = "0.0.1"
feats = json.loads((SCAN_DIR / f"{ds}__{v}__features.json").read_text())
find_image_keys_only(feats)
# Out:
# ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/encodingFormat',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/encodingFormat',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/pythonClassName']

# %%
def find_tfds_image_features(feats):
    hits = []

    def rec(o, path=""):
        if isinstance(o, dict):
            # TFDS Image pattern
            if (
                "image" in o
                and isinstance(o.get("image"), dict)
                and "shape" in o["image"]
                and "encodingFormat" in o["image"]
            ):
                hits.append(path)

            for k, v in o.items():
                rec(v, f"{path}/{k}")

        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")

    rec(feats)
    return hits

# %%
tfds_hits = []

for _, row in unknown_df.iterrows():
    ds = row["dataset"]
    v  = row["version"]
    feats = json.loads((SCAN_DIR / f"{ds}__{v}__features.json").read_text())

    hits = find_tfds_image_features(feats)
    tfds_hits.append({
        "dataset": ds,
        "version": v,
        "tfds_image_hits": len(hits),
        "paths": hits[:3] if hits else None
    })

tfds_df = pd.DataFrame(tfds_hits)
display(tfds_df)
# Out:
#                                       dataset version  tfds_image_hits  \
# 0                                        kuka   0.1.0                1
# 1                 columbia_cairlab_pusht_real   0.1.0                0
# 2                                   robot_vqa   0.1.0                1
# 3                        fractal20220817_data   0.1.0                1
# 4                                      bridge   0.1.0                0
# 5                                   jaco_play   0.1.0                0
# 6                      berkeley_cable_routing   0.1.0                0
# 7                                    roboturk   0.1.0                0
# 8   nyu_door_opening_surprising_effectiveness   0.1.0                0
# 9                        berkeley_autolab_ur5   0.1.0                0
# 10                                       toto   0.1.0                0
# 11                                      droid   1.0.1                3
# 12                     conq_hose_manipulation   0.0.1                3
# 13                                      dobbe   0.0.1                1
# 14                                        fmb   0.0.1                4
# 15                                 io_ai_tech   0.0.1                5
# 16                                 mimic_play   0.0.1                3
# 17                               aloha_mobile   0.0.1                3
# 18                                   robo_set   0.0.1                4
# 19                                    tidybot   0.0.1                1
# 20          vima_converted_externally_to_rlds   0.0.1                0
# 21                                       spoc   0.0.1                2
# 22                             plex_robosuite   0.0.1                2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       paths
# 0                                                                                                                                                                                                                                                                                                                                             [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 2                                                                                                                                                                                                                                                                                                                           [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/images/sequence/feature]
# 3                                                                                                                                                                                                                                                                                                                                             [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                      None
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 11                                                                       [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/exterior_image_1_left, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/exterior_image_2_left, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image_left]
# 12                                                                  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontleft_fisheye_image, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontright_fisheye_image, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_color_image]
# 13                                                                                                                                                                                                                                                                                                                                      [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image]
# 14                                                                                            [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_side_1, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_side_2, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist_1]
# 15                                                                                                          [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/depth, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_fisheye]
# 16  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/featuresDict/features/front_image_1, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/featuresDict/features/front_image_2, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/featuresDict/features/wrist_image]
# 17                                                                                            [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_high, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_left_wrist, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_right_wrist]
# 18                                                                                                   [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_left, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_right, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_top]
# 19                                                                                                                                                                                                                                                                                                                                            [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 21                                                                                                                                                                                                                  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_manipulation]
# 22                                                                                                                                                                                                                         [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image]

# %%
ds = "vima_converted_externally_to_rlds"
v = "0.0.1"
feats = json.loads((SCAN_DIR / f"{ds}__{v}__features.json").read_text())
find_image_keys_only(feats)
# Out:
# ['/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/length',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/feature/tensor/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_segmentation/sequence/length',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/length',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_segmentation/tensor/shape/dimensions',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/tensor',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/tensor/dtype',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/tensor/encoding',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/tensor/shape',
#  '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/tensor/shape/dimensions']

# %%
def find_tensor_image_features(feats):
    hits = []

    def rec(o, path=""):
        if isinstance(o, dict):
            # TensorSpec-like pattern
            if "tensor" in o and isinstance(o["tensor"], dict):
                t = o["tensor"]
                shp = t.get("shape", {})
                dims = shp.get("dimensions") if isinstance(shp, dict) else None
                if isinstance(dims, list) and len(dims) in (3,4) and dims[-1] in (1,3,4):
                    hits.append(path)

            for k, v in o.items():
                rec(v, f"{path}/{k}")

        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")

    rec(feats)
    return hits

# %%
still_zero = tfds_df[tfds_df["tfds_image_hits"] == 0].copy()
tensor_results = []

for _, r in still_zero.iterrows():
    ds, v = r["dataset"], r["version"]
    feats = json.loads((SCAN_DIR / f"{ds}__{v}__features.json").read_text())

    th = find_tensor_image_features(feats)
    tensor_results.append({
        "dataset": ds,
        "version": v,
        "tensor_image_hits": len(th),
        "tensor_paths": th[:3] if th else None,
    })

tensor_df = pd.DataFrame(tensor_results)
display(tensor_df)
# Out:
#                                      dataset version  tensor_image_hits  \
# 0                columbia_cairlab_pusht_real   0.1.0                  0
# 1                                     bridge   0.1.0                  0
# 2                                  jaco_play   0.1.0                  0
# 3                     berkeley_cable_routing   0.1.0                  0
# 4                                   roboturk   0.1.0                  0
# 5  nyu_door_opening_surprising_effectiveness   0.1.0                  0
# 6                       berkeley_autolab_ur5   0.1.0                  0
# 7                                       toto   0.1.0                  0
# 8          vima_converted_externally_to_rlds   0.0.1                  0
#
#   tensor_paths
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None

# %%
zero_list = tensor_df["dataset"].tolist()
for ds in zero_list:
    v = df.loc[df["dataset"] == ds, "version"].iloc[0]
    feats = json.loads((SCAN_DIR / f"{ds}__{v}__features.json").read_text())
    keys = find_image_keys_only(feats)
    print(ds, "keys:", len(keys))
    if keys:
        print("  ", keys[:10])
# Out:
# columbia_cairlab_pusht_real keys: 12
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/dtype', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape']
# bridge keys: 6
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/dtype']
# jaco_play keys: 12
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/image/dtype', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape']
# berkeley_cable_routing keys: 24
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/image/dtype', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist225_image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist225_image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist225_image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist225_image/image/shape']
# roboturk keys: 6
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/image/dtype']
# nyu_door_opening_surprising_effectiveness keys: 6
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/dtype']
# berkeley_autolab_ur5 keys: 18
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/dtype', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_image/image/shape']
# toto keys: 6
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions', '/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/dtype']
# vima_converted_externally_to_rlds keys: 54
#    ['/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/pythonClassName', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/dtype', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/encoding', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/shape', '/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/shape/dimensions']

# %%
def find_any_image_schema(feats):
    hits = []

    def rec(o, path=""):
        if isinstance(o, dict):
            # Case A: TFDS Image-like node: image -> shape -> dimensions
            img = o.get("image")
            if isinstance(img, dict):
                shp = img.get("shape")
                dims = shp.get("dimensions") if isinstance(shp, dict) else None
                if isinstance(dims, list) and len(dims) in (3, 4) and dims[-1] in (1, 3, 4):
                    hits.append((path, "image", dims, img.get("dtype"), img.get("encodingFormat")))

            # Case B: TensorSpec node: tensor -> shape -> dimensions
            t = o.get("tensor")
            if isinstance(t, dict):
                shp = t.get("shape")
                dims = shp.get("dimensions") if isinstance(shp, dict) else None
                if isinstance(dims, list) and len(dims) in (3, 4) and dims[-1] in (1, 3, 4):
                    hits.append((path, "tensor", dims, t.get("dtype"), t.get("encoding")))

            for k, v in o.items():
                rec(v, f"{path}/{k}")

        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")

    rec(feats)
    return hits

# %%
schema_rows = []

for _, row in df.iterrows():
    ds = row["dataset"]
    v  = row["version"]
    feats_path = SCAN_DIR / f"{ds}__{v}__features.json"

    if not feats_path.exists() or pd.isna(v):
        schema_rows.append({"dataset": ds, "schema_hits": 0, "schema_paths": None})
        continue

    feats = json.loads(feats_path.read_text())
    hits = find_any_image_schema(feats)

    schema_rows.append({
        "dataset": ds,
        "schema_hits": len(hits),
        "schema_paths": [h[0] for h in hits[:3]] if hits else None
    })

schema_df = pd.DataFrame(schema_rows)
df2 = df.merge(schema_df, on="dataset", how="left")
display(df2[["dataset","version","rgb_real","schema_hits","schema_paths","note"]])
# Out:
#                                                           dataset version  \
# 0                                                  language_table   0.1.0
# 1             stanford_hydra_dataset_converted_externally_to_rlds   0.1.0
# 2                austin_buds_dataset_converted_externally_to_rlds   0.1.0
# 3            furniture_bench_dataset_converted_externally_to_rlds   0.1.0
# 4     cmu_franka_exploration_dataset_converted_externally_to_rlds   0.1.0
# 5               ucsd_kitchen_dataset_converted_externally_to_rlds   0.1.0
# 6              austin_sirius_dataset_converted_externally_to_rlds   0.1.0
# 7   utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds   1.0.0
# 8                      utokyo_saytap_converted_externally_to_rlds   0.1.0
# 9                       berkeley_mvp_converted_externally_to_rlds   0.1.0
# 10               kaist_nonprehensile_converted_externally_to_rlds   0.1.0
# 11                     dlr_sara_pour_converted_externally_to_rlds   0.1.0
# 12                     asu_table_top_converted_externally_to_rlds   0.1.0
# 13                 stanford_robocook_converted_externally_to_rlds   0.1.0
# 14          iamlab_cmu_pickup_insert_converted_externally_to_rlds   0.1.0
# 15                                                 utaustin_mutex   0.1.0
# 16                                    berkeley_fanuc_manipulation   0.1.0
# 17                                          cmu_playing_with_food   1.0.0
# 18                                                    cmu_stretch   0.1.0
# 19                                         berkeley_gnm_cory_hall   0.1.0
# 20                                           berkeley_gnm_sac_son   0.1.0
# 21                                          eth_agent_affordances   0.1.0
# 22                                                           kuka   0.1.0
# 23                                    columbia_cairlab_pusht_real   0.1.0
# 24                                                      robot_vqa   0.1.0
# 25                                           fractal20220817_data   0.1.0
# 26                                                         bridge   0.1.0
# 27                                                      taco_play   0.1.0
# 28                                                      jaco_play   0.1.0
# 29                                         berkeley_cable_routing   0.1.0
# 30                                                       roboturk   0.1.0
# 31                      nyu_door_opening_surprising_effectiveness   0.1.0
# 32                                                          viola   0.1.0
# 33                                           berkeley_autolab_ur5   0.1.0
# 34                                                           toto   0.1.0
# 35  stanford_kuka_multimodal_dataset_converted_externally_to_rlds   0.1.0
# 36                   nyu_rot_dataset_converted_externally_to_rlds   0.1.0
# 37           nyu_franka_play_dataset_converted_externally_to_rlds   0.1.0
# 38                 maniskill_dataset_converted_externally_to_rlds   0.1.0
# 39       ucsd_pick_and_place_dataset_converted_externally_to_rlds   0.1.0
# 40             austin_sailor_dataset_converted_externally_to_rlds   0.1.0
# 41                                                           bc_z   1.0.1
# 42                     usc_cloth_sim_converted_externally_to_rlds   0.1.0
# 43         utokyo_pr2_opening_fridge_converted_externally_to_rlds   0.1.0
# 44        utokyo_xarm_pick_and_place_converted_externally_to_rlds   0.1.0
# 45              utokyo_xarm_bimanual_converted_externally_to_rlds   0.1.0
# 46                                                       robo_net   1.0.0
# 47                      berkeley_rpt_converted_externally_to_rlds   0.1.0
# 48                 stanford_mask_vit_converted_externally_to_rlds   0.1.0
# 49                      tokyo_u_lsmo_converted_externally_to_rlds   0.1.0
# 50               dlr_sara_grid_clamp_converted_externally_to_rlds   0.1.0
# 51           dlr_edan_shared_control_converted_externally_to_rlds   0.1.0
# 52                               imperialcollege_sawyer_wrist_cam   0.1.0
# 53                                     qut_dexterous_manipulation    None
# 54                                                   uiuc_d3field   1.1.2
# 55                                                cmu_play_fusion   0.1.0
# 56                                             berkeley_gnm_recon   0.1.0
# 57                                                          droid   1.0.1
# 58                                         conq_hose_manipulation   0.0.1
# 59                                                          dobbe   0.0.1
# 60                                                            fmb   0.0.1
# 61                                                     io_ai_tech   0.0.1
# 62                                                     mimic_play   0.0.1
# 63                                                   aloha_mobile   0.0.1
# 64                                                       robo_set   0.0.1
# 65                                                        tidybot   0.0.1
# 66                              vima_converted_externally_to_rlds   0.0.1
# 67                                                           spoc   0.0.1
# 68                                                 plex_robosuite   0.0.1
#
#    rgb_real  schema_hits schema_paths  \
# 0      True            0         None
# 1      True            0         None
# 2      True            0         None
# 3      True            0         None
# 4      True            0         None
# 5      True            0         None
# 6      True            0         None
# 7      True            0         None
# 8      True            0         None
# 9      True            0         None
# 10     True            0         None
# 11     True            0         None
# 12     True            0         None
# 13     True            0         None
# 14     True            0         None
# 15     True            0         None
# 16     True            0         None
# 17     True            0         None
# 18     True            0         None
# 19     True            0         None
# 20     True            0         None
# 21    False            0         None
# 22     None            0         None
# 23     None            0         None
# 24     None            0         None
# 25     None            0         None
# 26     None            0         None
# 27     True            0         None
# 28     None            0         None
# 29     None            0         None
# 30     None            0         None
# 31     None            0         None
# 32     True            0         None
# 33     None            0         None
# 34     None            0         None
# 35     True            0         None
# 36     True            0         None
# 37     True            0         None
# 38     True            0         None
# 39     True            0         None
# 40     True            0         None
# 41     True            0         None
# 42     True            0         None
# 43     True            0         None
# 44     True            0         None
# 45     True            0         None
# 46     True            0         None
# 47     True            0         None
# 48     True            0         None
# 49     True            0         None
# 50     True            0         None
# 51     True            0         None
# 52     True            0         None
# 53    False            0         None
# 54     True            0         None
# 55     True            0         None
# 56     True            0         None
# 57     None            0         None
# 58     None            0         None
# 59     None            0         None
# 60     None            0         None
# 61     None            0         None
# 62     None            0         None
# 63     None            0         None
# 64     None            0         None
# 65     None            0         None
# 66     None            0         None
# 67     None            0         None
# 68     None            0         None
#
#                                                                                                                                                                                                                    note
# 0                                                                                                                                                                                            An RGB image of the scene.
# 1                                                                                                                                                                                          Main camera RGB observation.
# 2                                                                                                                                                                                          Main camera RGB observation.
# 3                                                                                                                                                                                          Main camera RGB observation.
# 4                                                                                                                                                                                          Main camera RGB observation.
# 5                                                                                                                                                                                          Main camera RGB observation.
# 6                                                                                                                                                                                         Wrist camera RGB observation.
# 7                                                                                                                                                                                          Main camera RGB observation.
# 8                                                                                                                                                                                   Dummy wrist camera RGB observation.
# 9                                                                                                                                                                                          Hand camera RGB observation.
# 10                                                                                                                                                                                         Main camera RGB observation.
# 11                                                                                                                                                                                         Main camera RGB observation.
# 12                                                                                                                                                                                         Main camera RGB observation.
# 13                                                                                                                                                                                            Camera 1 RGB observation.
# 14                                                                                                                                                                                        Wrist camera RGB observation.
# 15                                                                                                                                                                                        Wrist camera RGB observation.
# 16                                                                                                                                                                                         Main camera RGB observation.
# 17                                                                                                                                                                                         Main camera RGB observation.
# 18                                                                                                                                                                                         Main camera RGB observation.
# 19                                                                                                                                                                                         Main camera RGB observation.
# 20                                                                                                                                                                                         Main camera RGB observation.
# 21                                                                                                                                Main camera RGB observation. Not available for this dataset, will be set to np.zeros.
# 22                                                                features.json downloaded (kuka__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/kuka/0.1.0/features.json but no image description hits
# 23                  features.json downloaded (columbia_cairlab_pusht_real__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/columbia_cairlab_pusht_real/0.1.0/features.json but no image description hits
# 24                                                      features.json downloaded (robot_vqa__0.1.0__features.json) from gs://gdm-robotics-open-x-embodiment/robot_vqa/0.1.0/features.json but no image description hits
# 25                                            features.json downloaded (fractal20220817_data__0.1.0__features.json) from gs://gresearch/robotics/fractal20220817_data/0.1.0/features.json but no image description hits
# 26                                                                        features.json downloaded (bridge__0.1.0__features.json) from gs://gresearch/robotics/bridge/0.1.0/features.json but no image description hits
# 27                                                                                                                                        RGB static image of shape. (150, 200, 3). Subsampled from (200,200, 3) image.
# 28                                                                  features.json downloaded (jaco_play__0.1.0__features.json) from gs://gresearch/robotics/jaco_play/0.1.0/features.json but no image description hits
# 29                                        features.json downloaded (berkeley_cable_routing__0.1.0__features.json) from gs://gresearch/robotics/berkeley_cable_routing/0.1.0/features.json but no image description hits
# 30                                                                    features.json downloaded (roboturk__0.1.0__features.json) from gs://gresearch/robotics/roboturk/0.1.0/features.json but no image description hits
# 31  features.json downloaded (nyu_door_opening_surprising_effectiveness__0.1.0__features.json) from gs://gresearch/robotics/nyu_door_opening_surprising_effectiveness/0.1.0/features.json but no image description hits
# 32                                                                                                                                                                                     RGB captured by workspace camera
# 33                                            features.json downloaded (berkeley_autolab_ur5__0.1.0__features.json) from gs://gresearch/robotics/berkeley_autolab_ur5/0.1.0/features.json but no image description hits
# 34                                                                            features.json downloaded (toto__0.1.0__features.json) from gs://gresearch/robotics/toto/0.1.0/features.json but no image description hits
# 35                                                                                                                                                                                       Main depth camera observation.
# 36                                                                                                                                                                                         Main camera RGB observation.
# 37                                                                                                                                                                                        Right camera RGB observation.
# 38                                                                                                                                                                                         Main camera RGB observation.
# 39                                                                                                                                                                                              Camera RGB observation.
# 40                                                                                                                                                                                         Main camera RGB observation.
# 41                                                                                                                                                                            Camera image of the robot, downsampled 3x
# 42                                                                                                                                                                                          Image observation of cloth.
# 43                                                                                                                                                                                         Main camera RGB observation.
# 44                                                                                                                                                                                         Main camera RGB observation.
# 45                                                                                                                                                                                         Main camera RGB observation.
# 46                                                                                                                                                                                         Main camera RGB observation.
# 47                                                                                                                                                                                         Hand camera RGB observation.
# 48                                                                                                                                                                                         Main camera RGB observation.
# 49                                                                                                                                                                                         Main camera RGB observation.
# 50                                                                                                                                                                                         Main camera RGB observation.
# 51                                                                                                                                                                                         Main camera RGB observation.
# 52                                                                                                                                                                                        Wrist camera RGB observation.
# 53                                         error: gsutil failed (1)\nCMD: gsutil ls "gs://gresearch/robotics/qut_dexterous_manipulation/"\nSTDOUT:\n\nSTDERR:\nCommandException: One or more URLs matched no objects.\n
# 54                                                                                                                                                                                            camera 1 RGB observation.
# 55                                                                                                                                                                                         Main camera RGB observation.
# 56                                                                                                                                                                                         Main camera RGB observation.
# 57                                                                          features.json downloaded (droid__1.0.1__features.json) from gs://gresearch/robotics/droid/1.0.1/features.json but no image description hits
# 58                                        features.json downloaded (conq_hose_manipulation__0.0.1__features.json) from gs://gresearch/robotics/conq_hose_manipulation/0.0.1/features.json but no image description hits
# 59                                                                          features.json downloaded (dobbe__0.0.1__features.json) from gs://gresearch/robotics/dobbe/0.0.1/features.json but no image description hits
# 60                                                                              features.json downloaded (fmb__0.0.1__features.json) from gs://gresearch/robotics/fmb/0.0.1/features.json but no image description hits
# 61                                                                features.json downloaded (io_ai_tech__0.0.1__features.json) from gs://gresearch/robotics/io_ai_tech/0.0.1/features.json but no image description hits
# 62                                                                features.json downloaded (mimic_play__0.0.1__features.json) from gs://gresearch/robotics/mimic_play/0.0.1/features.json but no image description hits
# 63                                                            features.json downloaded (aloha_mobile__0.0.1__features.json) from gs://gresearch/robotics/aloha_mobile/0.0.1/features.json but no image description hits
# 64                                                                    features.json downloaded (robo_set__0.0.1__features.json) from gs://gresearch/robotics/robo_set/0.0.1/features.json but no image description hits
# 65                                                                      features.json downloaded (tidybot__0.0.1__features.json) from gs://gresearch/robotics/tidybot/0.0.1/features.json but no image description hits
# 66                  features.json downloaded (vima_converted_externally_to_rlds__0.0.1__features.json) from gs://gresearch/robotics/vima_converted_externally_to_rlds/0.0.1/features.json but no image description hits
# 67                                                                            features.json downloaded (spoc__0.0.1__features.json) from gs://gresearch/robotics/spoc/0.0.1/features.json but no image description hits
# 68                                                        features.json downloaded (plex_robosuite__0.0.1__features.json) from gs://gresearch/robotics/plex_robosuite/0.0.1/features.json but no image description hits

# %%
def rgb_status(row):
    if row["rgb_real"] is True:
        return "CONFIRMED_RGB (description)"
    if row["rgb_real"] is False:
        return "CONFIRMED_NO_RGB (explicit zeros/unavailable)"
    if (row.get("schema_hits") or 0) > 0:
        return "CONFIRMED_RGB (schema)"
    return "RGB_UNKNOWN (needs runtime check)"

df2["rgb_status"] = df2.apply(rgb_status, axis=1)
df2["rgb_status"].value_counts()
# Out:
# rgb_status
# CONFIRMED_RGB (description)                      44
# RGB_UNKNOWN (needs runtime check)                23
# CONFIRMED_NO_RGB (explicit zeros/unavailable)     2
# Name: count, dtype: int64

# %%
import re

IMG_KEY_RE = re.compile(r"(image|rgb|camera|wrist|front|left|right|top|side|fisheye)", re.I)

def _parse_dims_from_any(shape_obj):
    """
    Returns dims as a list of ints if we can interpret them, else None.
    Handles:
      - {"dimensions":[150,200,3]}
      - {"dimensions":[{"size":150},{"size":200},{"size":3}]}
      - [150,200,3]
      - {"dims":[...]} / {"dim":[...]} / {"size":[...]} (fallback keys)
    """
    if shape_obj is None:
        return None

    # case: shape is directly a list
    if isinstance(shape_obj, list) and all(isinstance(x, int) for x in shape_obj):
        return shape_obj

    if isinstance(shape_obj, dict):
        # try common keys
        for key in ("dimensions", "dims", "dim", "sizes", "size"):
            if key in shape_obj:
                d = shape_obj[key]

                # dims are ints
                if isinstance(d, list) and all(isinstance(x, int) for x in d):
                    return d

                # dims are list of dicts like {"size":150}
                if isinstance(d, list) and all(isinstance(x, dict) for x in d):
                    out = []
                    for x in d:
                        # common fields inside a dimension object
                        for k2 in ("size", "value", "dim", "dimension"):
                            if k2 in x and isinstance(x[k2], int):
                                out.append(x[k2])
                                break
                    if out:
                        return out

    return None


def find_image_dims_flexible(feats):
    hits = []

    def rec(o, path=""):
        if isinstance(o, dict):
            # if this node has a "shape" key, try parse it
            if "shape" in o:
                dims = _parse_dims_from_any(o.get("shape"))
                if isinstance(dims, list) and len(dims) in (3, 4) and dims[-1] in (1, 3, 4):
                    if IMG_KEY_RE.search(path):
                        hits.append((path + "/shape", dims))

            for k, v in o.items():
                rec(v, f"{path}/{k}")

        elif isinstance(o, list):
            for i, v in enumerate(o):
                rec(v, f"{path}[{i}]")

    rec(feats)
    return hits

# %%
ds="bridge"; v="0.1.0"
feats=json.loads((SCAN_DIR/f"{ds}__{v}__features.json").read_text())
hits = find_image_dims_flexible(feats)
len(hits), hits[:10]
# Out:
# (0, [])

# %%
import re

def get_by_path(obj, path):
    cur = obj
    # split "/a/b[0]/c" into tokens
    tokens = [t for t in path.strip("/").split("/") if t]
    for tok in tokens:
        m = re.match(r"^(.*)\[(\d+)\]$", tok)
        if m:
            key, idx = m.group(1), int(m.group(2))
            cur = cur[key][idx]
        else:
            cur = cur[tok]
    return cur

# %%
shape_path = "/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape"
dims_path  = shape_path + "/dimensions"

shape_obj = get_by_path(feats, shape_path)
dims_obj  = get_by_path(feats, dims_path)

print("shape_obj type:", type(shape_obj))
print("shape_obj:", shape_obj)
print("dims_obj type:", type(dims_obj))
print("dims_obj:", dims_obj)
# Out:
# shape_obj type: <class 'dict'>
# shape_obj: {'dimensions': ['480', '640', '3']}
# dims_obj type: <class 'list'>
# dims_obj: ['480', '640', '3']

# %%
def dims_from_key_paths(feats, keys):
    dims_hits = []
    for k in keys:
        if k.endswith("/shape/dimensions"):
            try:
                dims_obj = get_by_path(feats, k)
                dims_hits.append((k, dims_obj))
            except Exception:
                pass
    return dims_hits

keys = find_image_keys_only(feats)
dims_hits = dims_from_key_paths(feats, keys)
print("dims_hits:", len(dims_hits))
dims_hits[:10]
# Out:
# dims_hits: 1
# [('/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape/dimensions',
#   ['480', '640', '3'])]

# %%
def _to_int_list(x):
    """
    Convert dims that may be ints or numeric strings into a list[int].
    Returns None if conversion isn't clean.
    """
    if not isinstance(x, list):
        return None

    out = []
    for v in x:
        if isinstance(v, int):
            out.append(v)
        elif isinstance(v, str) and v.strip().isdigit():
            out.append(int(v.strip()))
        else:
            return None
    return out

# %%
def _parse_dims_from_any(shape_obj):
    if shape_obj is None:
        return None

    # shape is directly a list
    if isinstance(shape_obj, list):
        return _to_int_list(shape_obj)

    if isinstance(shape_obj, dict):
        for key in ("dimensions", "dims", "dim", "sizes", "size"):
            if key in shape_obj:
                d = shape_obj[key]

                # list of ints or numeric strings
                if isinstance(d, list):
                    ints = _to_int_list(d)
                    if ints is not None:
                        return ints

                # list of dicts like {"size":"480"}
                if isinstance(d, list) and all(isinstance(x, dict) for x in d):
                    out = []
                    for x in d:
                        for k2 in ("size", "value", "dim", "dimension"):
                            if k2 in x:
                                vv = x[k2]
                                if isinstance(vv, int):
                                    out.append(vv)
                                    break
                                if isinstance(vv, str) and vv.strip().isdigit():
                                    out.append(int(vv.strip()))
                                    break
                    if out:
                        return out

    return None

# %%
ds="bridge"; v="0.1.0"
feats=json.loads((SCAN_DIR/f"{ds}__{v}__features.json").read_text())
hits = find_image_dims_flexible(feats)
len(hits), hits[:10]
# Out:
# (1,
#  [('/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape',
#    [480, 640, 3])])

# %%
schema_rows = []
for _, row in df.iterrows():
    ds = row["dataset"]
    v  = row["version"]
    feats_path = SCAN_DIR / f"{ds}__{v}__features.json"

    if not feats_path.exists() or pd.isna(v):
        schema_rows.append({"dataset": ds, "schema_hits": 0, "schema_paths": None})
        continue

    feats = json.loads(feats_path.read_text())
    hits = find_image_dims_flexible(feats)

    schema_rows.append({
        "dataset": ds,
        "schema_hits": len(hits),
        "schema_paths": [h[0] for h in hits[:3]] if hits else None
    })

schema_df = pd.DataFrame(schema_rows)
df4 = df.merge(schema_df, on="dataset", how="left")

df4["rgb_status"] = df4.apply(rgb_status, axis=1)
df4["rgb_status"].value_counts()
# Out:
# rgb_status
# CONFIRMED_RGB (description)                      44
# CONFIRMED_RGB (schema)                           23
# CONFIRMED_NO_RGB (explicit zeros/unavailable)     2
# Name: count, dtype: int64

# %%
final_df = df.merge(schema_df, on="dataset", how="left")

def classify_row(row):
    if row["rgb_real"] is True:
        return (
            "CONFIRMED_RGB",
            "description",
            None,
            row["note"]
        )

    if row["rgb_real"] is False:
        return (
            "CONFIRMED_NO_RGB",
            "explicit_zero",
            None,
            row["note"]
        )

    if (row.get("schema_hits") or 0) > 0:
        return (
            "CONFIRMED_RGB",
            "schema",
            row["schema_paths"],
            "RGB confirmed via TFDS/RLDS image schema"
        )

    return (
        "RGB_UNKNOWN",
        "runtime_required",
        None,
        "No image description or schema; requires runtime episode inspection"
    )

final_df[
    ["rgb_status", "rgb_evidence", "rgb_paths", "final_note"]
] = final_df.apply(
    lambda r: pd.Series(classify_row(r)),
    axis=1
)

# %%
final_df = final_df[[
    "dataset",
    "version",
    "rgb_status",
    "rgb_evidence",
    "rgb_paths",
    "final_note"
]]

final_df
# Out:
#                                                           dataset version  \
# 0                                                  language_table   0.1.0
# 1             stanford_hydra_dataset_converted_externally_to_rlds   0.1.0
# 2                austin_buds_dataset_converted_externally_to_rlds   0.1.0
# 3            furniture_bench_dataset_converted_externally_to_rlds   0.1.0
# 4     cmu_franka_exploration_dataset_converted_externally_to_rlds   0.1.0
# 5               ucsd_kitchen_dataset_converted_externally_to_rlds   0.1.0
# 6              austin_sirius_dataset_converted_externally_to_rlds   0.1.0
# 7   utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds   1.0.0
# 8                      utokyo_saytap_converted_externally_to_rlds   0.1.0
# 9                       berkeley_mvp_converted_externally_to_rlds   0.1.0
# 10               kaist_nonprehensile_converted_externally_to_rlds   0.1.0
# 11                     dlr_sara_pour_converted_externally_to_rlds   0.1.0
# 12                     asu_table_top_converted_externally_to_rlds   0.1.0
# 13                 stanford_robocook_converted_externally_to_rlds   0.1.0
# 14          iamlab_cmu_pickup_insert_converted_externally_to_rlds   0.1.0
# 15                                                 utaustin_mutex   0.1.0
# 16                                    berkeley_fanuc_manipulation   0.1.0
# 17                                          cmu_playing_with_food   1.0.0
# 18                                                    cmu_stretch   0.1.0
# 19                                         berkeley_gnm_cory_hall   0.1.0
# 20                                           berkeley_gnm_sac_son   0.1.0
# 21                                          eth_agent_affordances   0.1.0
# 22                                                           kuka   0.1.0
# 23                                    columbia_cairlab_pusht_real   0.1.0
# 24                                                      robot_vqa   0.1.0
# 25                                           fractal20220817_data   0.1.0
# 26                                                         bridge   0.1.0
# 27                                                      taco_play   0.1.0
# 28                                                      jaco_play   0.1.0
# 29                                         berkeley_cable_routing   0.1.0
# 30                                                       roboturk   0.1.0
# 31                      nyu_door_opening_surprising_effectiveness   0.1.0
# 32                                                          viola   0.1.0
# 33                                           berkeley_autolab_ur5   0.1.0
# 34                                                           toto   0.1.0
# 35  stanford_kuka_multimodal_dataset_converted_externally_to_rlds   0.1.0
# 36                   nyu_rot_dataset_converted_externally_to_rlds   0.1.0
# 37           nyu_franka_play_dataset_converted_externally_to_rlds   0.1.0
# 38                 maniskill_dataset_converted_externally_to_rlds   0.1.0
# 39       ucsd_pick_and_place_dataset_converted_externally_to_rlds   0.1.0
# 40             austin_sailor_dataset_converted_externally_to_rlds   0.1.0
# 41                                                           bc_z   1.0.1
# 42                     usc_cloth_sim_converted_externally_to_rlds   0.1.0
# 43         utokyo_pr2_opening_fridge_converted_externally_to_rlds   0.1.0
# 44        utokyo_xarm_pick_and_place_converted_externally_to_rlds   0.1.0
# 45              utokyo_xarm_bimanual_converted_externally_to_rlds   0.1.0
# 46                                                       robo_net   1.0.0
# 47                      berkeley_rpt_converted_externally_to_rlds   0.1.0
# 48                 stanford_mask_vit_converted_externally_to_rlds   0.1.0
# 49                      tokyo_u_lsmo_converted_externally_to_rlds   0.1.0
# 50               dlr_sara_grid_clamp_converted_externally_to_rlds   0.1.0
# 51           dlr_edan_shared_control_converted_externally_to_rlds   0.1.0
# 52                               imperialcollege_sawyer_wrist_cam   0.1.0
# 53                                     qut_dexterous_manipulation    None
# 54                                                   uiuc_d3field   1.1.2
# 55                                                cmu_play_fusion   0.1.0
# 56                                             berkeley_gnm_recon   0.1.0
# 57                                                          droid   1.0.1
# 58                                         conq_hose_manipulation   0.0.1
# 59                                                          dobbe   0.0.1
# 60                                                            fmb   0.0.1
# 61                                                     io_ai_tech   0.0.1
# 62                                                     mimic_play   0.0.1
# 63                                                   aloha_mobile   0.0.1
# 64                                                       robo_set   0.0.1
# 65                                                        tidybot   0.0.1
# 66                              vima_converted_externally_to_rlds   0.0.1
# 67                                                           spoc   0.0.1
# 68                                                 plex_robosuite   0.0.1
#
#           rgb_status   rgb_evidence  \
# 0      CONFIRMED_RGB    description
# 1      CONFIRMED_RGB    description
# 2      CONFIRMED_RGB    description
# 3      CONFIRMED_RGB    description
# 4      CONFIRMED_RGB    description
# 5      CONFIRMED_RGB    description
# 6      CONFIRMED_RGB    description
# 7      CONFIRMED_RGB    description
# 8      CONFIRMED_RGB    description
# 9      CONFIRMED_RGB    description
# 10     CONFIRMED_RGB    description
# 11     CONFIRMED_RGB    description
# 12     CONFIRMED_RGB    description
# 13     CONFIRMED_RGB    description
# 14     CONFIRMED_RGB    description
# 15     CONFIRMED_RGB    description
# 16     CONFIRMED_RGB    description
# 17     CONFIRMED_RGB    description
# 18     CONFIRMED_RGB    description
# 19     CONFIRMED_RGB    description
# 20     CONFIRMED_RGB    description
# 21  CONFIRMED_NO_RGB  explicit_zero
# 22     CONFIRMED_RGB         schema
# 23     CONFIRMED_RGB         schema
# 24     CONFIRMED_RGB         schema
# 25     CONFIRMED_RGB         schema
# 26     CONFIRMED_RGB         schema
# 27     CONFIRMED_RGB    description
# 28     CONFIRMED_RGB         schema
# 29     CONFIRMED_RGB         schema
# 30     CONFIRMED_RGB         schema
# 31     CONFIRMED_RGB         schema
# 32     CONFIRMED_RGB    description
# 33     CONFIRMED_RGB         schema
# 34     CONFIRMED_RGB         schema
# 35     CONFIRMED_RGB    description
# 36     CONFIRMED_RGB    description
# 37     CONFIRMED_RGB    description
# 38     CONFIRMED_RGB    description
# 39     CONFIRMED_RGB    description
# 40     CONFIRMED_RGB    description
# 41     CONFIRMED_RGB    description
# 42     CONFIRMED_RGB    description
# 43     CONFIRMED_RGB    description
# 44     CONFIRMED_RGB    description
# 45     CONFIRMED_RGB    description
# 46     CONFIRMED_RGB    description
# 47     CONFIRMED_RGB    description
# 48     CONFIRMED_RGB    description
# 49     CONFIRMED_RGB    description
# 50     CONFIRMED_RGB    description
# 51     CONFIRMED_RGB    description
# 52     CONFIRMED_RGB    description
# 53  CONFIRMED_NO_RGB  explicit_zero
# 54     CONFIRMED_RGB    description
# 55     CONFIRMED_RGB    description
# 56     CONFIRMED_RGB    description
# 57     CONFIRMED_RGB         schema
# 58     CONFIRMED_RGB         schema
# 59     CONFIRMED_RGB         schema
# 60     CONFIRMED_RGB         schema
# 61     CONFIRMED_RGB         schema
# 62     CONFIRMED_RGB         schema
# 63     CONFIRMED_RGB         schema
# 64     CONFIRMED_RGB         schema
# 65     CONFIRMED_RGB         schema
# 66     CONFIRMED_RGB         schema
# 67     CONFIRMED_RGB         schema
# 68     CONFIRMED_RGB         schema
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       rgb_paths  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 22                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 23                                                                                                                                                                                                                                     [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 24                                                                                                                                                                                                                                                                                                                                                  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/images/sequence/feature/image/shape]
# 25                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 26                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 28                                                                                                                                                                                                                                     [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 29                                                                                             [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/top_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist225_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist45_image/image/shape]
# 30                                                                                                                                                                                                                                                                                                                                                                [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/front_rgb/image/shape]
# 31                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 33                                                                                                  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_with_depth/image/shape]
# 34                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None
# 57                                                                       [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/exterior_image_1_left/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/exterior_image_2_left/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image_left/image/shape]
# 58                                                                  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontleft_fisheye_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontright_fisheye_image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/hand_color_image/image/shape]
# 59                                                                                                                                                                                                                                                                                                                                                              [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape]
# 60                                                                                            [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_side_1/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_side_2/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_wrist_1/image/shape]
# 61                                                                                                          [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/depth/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_fisheye/image/shape]
# 62  [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/featuresDict/features/front_image_1/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/featuresDict/features/front_image_2/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/featuresDict/features/wrist_image/image/shape]
# 63                                                                                            [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_high/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_left_wrist/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/cam_right_wrist/image/shape]
# 64                                                                                                   [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_left/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_right/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_top/image/shape]
# 65                                                                                                                                                                                                                                                                                                                                                                    [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape]
# 66                         [/featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/frontal_image/sequence/feature/tensor/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/multimodal_instruction_assets/featuresDict/features/image/sequence/feature/tensor/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/frontal_image/tensor/shape]
# 67                                                                                                                                                                                                                              [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image_manipulation/image/shape]
# 68                                                                                                                                                                                                                                     [/featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/image/image/shape, /featuresDict/features/steps/sequence/feature/featuresDict/features/observation/featuresDict/features/wrist_image/image/shape]
#
#                                                                                                                                                                       final_note
# 0                                                                                                                                                     An RGB image of the scene.
# 1                                                                                                                                                   Main camera RGB observation.
# 2                                                                                                                                                   Main camera RGB observation.
# 3                                                                                                                                                   Main camera RGB observation.
# 4                                                                                                                                                   Main camera RGB observation.
# 5                                                                                                                                                   Main camera RGB observation.
# 6                                                                                                                                                  Wrist camera RGB observation.
# 7                                                                                                                                                   Main camera RGB observation.
# 8                                                                                                                                            Dummy wrist camera RGB observation.
# 9                                                                                                                                                   Hand camera RGB observation.
# 10                                                                                                                                                  Main camera RGB observation.
# 11                                                                                                                                                  Main camera RGB observation.
# 12                                                                                                                                                  Main camera RGB observation.
# 13                                                                                                                                                     Camera 1 RGB observation.
# 14                                                                                                                                                 Wrist camera RGB observation.
# 15                                                                                                                                                 Wrist camera RGB observation.
# 16                                                                                                                                                  Main camera RGB observation.
# 17                                                                                                                                                  Main camera RGB observation.
# 18                                                                                                                                                  Main camera RGB observation.
# 19                                                                                                                                                  Main camera RGB observation.
# 20                                                                                                                                                  Main camera RGB observation.
# 21                                                                                         Main camera RGB observation. Not available for this dataset, will be set to np.zeros.
# 22                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 23                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 24                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 25                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 26                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 27                                                                                                 RGB static image of shape. (150, 200, 3). Subsampled from (200,200, 3) image.
# 28                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 29                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 30                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 31                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 32                                                                                                                                              RGB captured by workspace camera
# 33                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 34                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 35                                                                                                                                                Main depth camera observation.
# 36                                                                                                                                                  Main camera RGB observation.
# 37                                                                                                                                                 Right camera RGB observation.
# 38                                                                                                                                                  Main camera RGB observation.
# 39                                                                                                                                                       Camera RGB observation.
# 40                                                                                                                                                  Main camera RGB observation.
# 41                                                                                                                                     Camera image of the robot, downsampled 3x
# 42                                                                                                                                                   Image observation of cloth.
# 43                                                                                                                                                  Main camera RGB observation.
# 44                                                                                                                                                  Main camera RGB observation.
# 45                                                                                                                                                  Main camera RGB observation.
# 46                                                                                                                                                  Main camera RGB observation.
# 47                                                                                                                                                  Hand camera RGB observation.
# 48                                                                                                                                                  Main camera RGB observation.
# 49                                                                                                                                                  Main camera RGB observation.
# 50                                                                                                                                                  Main camera RGB observation.
# 51                                                                                                                                                  Main camera RGB observation.
# 52                                                                                                                                                 Wrist camera RGB observation.
# 53  error: gsutil failed (1)\nCMD: gsutil ls "gs://gresearch/robotics/qut_dexterous_manipulation/"\nSTDOUT:\n\nSTDERR:\nCommandException: One or more URLs matched no objects.\n
# 54                                                                                                                                                     camera 1 RGB observation.
# 55                                                                                                                                                  Main camera RGB observation.
# 56                                                                                                                                                  Main camera RGB observation.
# 57                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 58                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 59                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 60                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 61                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 62                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 63                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 64                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 65                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 66                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 67                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
# 68                                                                                                                                      RGB confirmed via TFDS/RLDS image schema
