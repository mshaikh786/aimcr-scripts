# %%
import sys
# !{sys.executable} -m pip install -U ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in ./envs/llava-video-investigation/lib/python3.10/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in ./envs/llava-video-investigation/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/x_mohameta/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in ./envs/llava-video-investigation/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./envs/llava-video-investigation/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in ./envs/llava-video-investigation/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from datasets import get_dataset_config_names

DATASET_ID = "lmms-lab/LLaVA-Video-178K"

configs = get_dataset_config_names(DATASET_ID)
print("num configs:", len(configs))
for c in configs:
    print(c)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# num configs: 19
# 0_30_s_academic_v0_1
# 0_30_s_youtube_v0_1
# 0_30_s_activitynet
# 0_30_s_perceptiontest
# 0_30_s_nextqa
# 30_60_s_academic_v0_1
# 30_60_s_youtube_v0_1
# 30_60_s_activitynet
# 30_60_s_perceptiontest
# 30_60_s_nextqa
# 1_2_m_youtube_v0_1
# 1_2_m_academic_v0_1
# 1_2_m_activitynet
# 1_2_m_nextqa
# 2_3_m_youtube_v0_1
# 2_3_m_academic_v0_1
# 2_3_m_activitynet
# 2_3_m_nextqa
# llava_hound

# %%
from __future__ import annotations

import os
from collections import Counter, defaultdict
from pprint import pformat
from typing import Any, Dict, List, Tuple

import pandas as pd
from datasets import load_dataset_builder, load_dataset, get_dataset_config_names

DATASET_ID = "lmms-lab/LLaVA-Video-178K"
CONFIGS = get_dataset_config_names(DATASET_ID)

VIDEO_EXTS = {".mp4", ".webm", ".mkv", ".mov", ".avi", ".m4v"}
IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".bmp"}


def shallow_preview(x: Any, max_str=160) -> Any:
    if isinstance(x, str):
        s = x.replace("\n", "\\n")
        return s if len(s) <= max_str else s[:max_str] + "…"
    if isinstance(x, (int, float, bool)) or x is None:
        return x
    if isinstance(x, dict):
        keys = list(x.keys())
        out = {}
        for k in keys[:3]:
            out[k] = shallow_preview(x[k], max_str=max_str)
        if len(keys) > 3:
            out["…"] = f"+{len(keys)-3} more keys"
        return out
    if isinstance(x, list):
        out = [shallow_preview(v, max_str=max_str) for v in x[:2]]
        if len(x) > 2:
            out.append(f"… +{len(x)-2} more items")
        return out
    return f"<{type(x).__name__}>"


def iter_leaf_paths(obj: Any, prefix=""):
    if isinstance(obj, dict):
        for k, v in obj.items():
            p = f"{prefix}.{k}" if prefix else k
            yield from iter_leaf_paths(v, p)
    elif isinstance(obj, list):
        for i, v in enumerate(obj):
            p = f"{prefix}[{i}]"
            yield from iter_leaf_paths(v, p)
    else:
        yield prefix, obj


def detect_media_from_example(ex: Dict[str, Any]) -> Tuple[List[Tuple[str, str]], Dict[str, Counter]]:
    media_fields = []
    formats = defaultdict(Counter)

    for path, val in iter_leaf_paths(ex):
        p = None
        if isinstance(val, str):
            p = val
        elif isinstance(val, dict) and isinstance(val.get("path"), str):
            p = val["path"]

        if not p:
            continue

        _, ext = os.path.splitext(p)
        ext = ext.lower()

        if ext in VIDEO_EXTS:
            media_fields.append((path, "video"))
            formats[path][ext] += 1
        elif ext in IMAGE_EXTS:
            media_fields.append((path, "image"))
            formats[path][ext] += 1

    seen = set()
    uniq = []
    for p, k in media_fields:
        if p not in seen:
            uniq.append((p, k))
            seen.add(p)

    return uniq, formats


def get_available_splits(cfg: str) -> List[str]:
    try:
        b = load_dataset_builder(DATASET_ID, name=cfg)
        if b.info and b.info.splits:
            return list(b.info.splits.keys())
    except Exception:
        pass

    # based on your earlier error messages
    candidates = ["caption", "open_ended", "multi_choice"]
    found = []
    for s in candidates:
        try:
            _ = load_dataset(DATASET_ID, name=cfg, split=s, streaming=True)
            found.append(s)
        except Exception:
            pass
    return found


def try_get_num_examples(cfg: str, split: str):
    try:
        b = load_dataset_builder(DATASET_ID, name=cfg)
        sinfo = b.info.splits.get(split) if b.info and b.info.splits else None
        return getattr(sinfo, "num_examples", None) if sinfo else None
    except Exception:
        return None


def get_one_example(cfg: str, split: str) -> Tuple[Dict[str, Any] | None, str | None]:
    """
    Returns (example, error_str).
    Tries streaming first, then fallback to non-streaming minimal slice.
    """
    # 1) streaming
    try:
        ds_stream = load_dataset(DATASET_ID, name=cfg, split=split, streaming=True)
        it = iter(ds_stream)
        ex = next(it, None)
        if ex is not None:
            return ex, None
    except Exception as e:
        # keep error but still try fallback
        stream_err = repr(e)
    else:
        stream_err = "StopIteration (empty stream)"

    # 2) fallback: non-streaming minimal slice
    try:
        ds_one = load_dataset(DATASET_ID, name=cfg, split=f"{split}[:1]")
        if len(ds_one) > 0:
            return ds_one[0], None
        return None, "Non-streaming returned 0 rows"
    except Exception as e:
        return None, f"Streaming failed: {stream_err} | Fallback failed: {repr(e)}"


rows = []

for cfg in CONFIGS:
    splits = get_available_splits(cfg)

    for split in splits:
        n_examples = try_get_num_examples(cfg, split)

        ex, err = get_one_example(cfg, split)
        if ex is None:
            rows.append({
                "config": cfg,
                "split": split,
                "num_examples_meta": n_examples,
                "top_level_keys": [],
                "media_fields_detected": "<none>",
                "formats_inferred": {},
                "sample_preview": {},
                "status": "FAILED",
                "error": err,
            })
            continue

        media_fields, formats = detect_media_from_example(ex)

        keys = list(ex.keys()) if isinstance(ex, dict) else []
        preview = {k: shallow_preview(ex[k]) for k in keys[:12]}
        if len(keys) > 12:
            preview["…"] = f"+{len(keys)-12} more keys"

        rows.append({
            "config": cfg,
            "split": split,
            "num_examples_meta": n_examples,
            "top_level_keys": keys,
            "media_fields_detected": ", ".join([f"{p}({k})" for p, k in media_fields]) or "<none_detected>",
            "formats_inferred": {p: dict(c.most_common(5)) for p, c in formats.items()},
            "sample_preview": preview,
            "status": "OK",
            "error": None,
        })

df = pd.DataFrame(rows)
df
# Out:
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
#                     config         split num_examples_meta  \
# 0     0_30_s_academic_v0_1       caption              None
# 1     0_30_s_academic_v0_1    open_ended              None
# 2     0_30_s_academic_v0_1  multi_choice              None
# 3      0_30_s_youtube_v0_1       caption              None
# 4      0_30_s_youtube_v0_1    open_ended              None
# 5      0_30_s_youtube_v0_1  multi_choice              None
# 6       0_30_s_activitynet    open_ended              None
# 7    0_30_s_perceptiontest  multi_choice              None
# 8            0_30_s_nextqa    open_ended              None
# 9            0_30_s_nextqa  multi_choice              None
# 10   30_60_s_academic_v0_1       caption              None
# 11   30_60_s_academic_v0_1    open_ended              None
# 12   30_60_s_academic_v0_1  multi_choice              None
# 13    30_60_s_youtube_v0_1       caption              None
# 14    30_60_s_youtube_v0_1    open_ended              None
# 15    30_60_s_youtube_v0_1  multi_choice              None
# 16     30_60_s_activitynet    open_ended              None
# 17  30_60_s_perceptiontest  multi_choice              None
# 18          30_60_s_nextqa    open_ended              None
# 19          30_60_s_nextqa  multi_choice              None
# 20      1_2_m_youtube_v0_1       caption              None
# 21      1_2_m_youtube_v0_1    open_ended              None
# 22      1_2_m_youtube_v0_1  multi_choice              None
# 23     1_2_m_academic_v0_1       caption              None
# 24     1_2_m_academic_v0_1    open_ended              None
# 25     1_2_m_academic_v0_1  multi_choice              None
# 26       1_2_m_activitynet    open_ended              None
# 27            1_2_m_nextqa    open_ended              None
# 28            1_2_m_nextqa  multi_choice              None
# 29      2_3_m_youtube_v0_1       caption              None
# 30      2_3_m_youtube_v0_1    open_ended              None
# 31      2_3_m_youtube_v0_1  multi_choice              None
# 32     2_3_m_academic_v0_1       caption              None
# 33     2_3_m_academic_v0_1    open_ended              None
# 34     2_3_m_academic_v0_1  multi_choice              None
# 35       2_3_m_activitynet    open_ended              None
# 36            2_3_m_nextqa    open_ended              None
# 37            2_3_m_nextqa  multi_choice              None
# 38             llava_hound    open_ended              None
#
#                              top_level_keys media_fields_detected  \
# 0   [id, conversations, data_source, video]          video(video)
# 1   [id, conversations, data_source, video]          video(video)
# 2   [id, conversations, data_source, video]          video(video)
# 3   [id, conversations, data_source, video]          video(video)
# 4   [id, conversations, data_source, video]          video(video)
# 5   [id, conversations, data_source, video]          video(video)
# 6                                        []                <none>
# 7   [id, conversations, data_source, video]          video(video)
# 8   [id, conversations, data_source, video]          video(video)
# 9   [id, conversations, data_source, video]          video(video)
# 10  [id, conversations, data_source, video]          video(video)
# 11  [id, conversations, data_source, video]          video(video)
# 12  [id, conversations, data_source, video]          video(video)
# 13  [id, conversations, data_source, video]          video(video)
# 14  [id, conversations, data_source, video]          video(video)
# 15  [id, conversations, data_source, video]          video(video)
# 16                                       []                <none>
# 17  [id, conversations, data_source, video]          video(video)
# 18  [id, conversations, data_source, video]          video(video)
# 19  [id, conversations, data_source, video]          video(video)
# 20  [id, conversations, data_source, video]          video(video)
# 21  [id, conversations, data_source, video]          video(video)
# 22  [id, conversations, data_source, video]          video(video)
# 23  [id, conversations, data_source, video]          video(video)
# 24  [id, conversations, data_source, video]          video(video)
# 25  [id, conversations, data_source, video]          video(video)
# 26                                       []                <none>
# 27  [id, conversations, data_source, video]          video(video)
# 28  [id, conversations, data_source, video]          video(video)
# 29  [id, conversations, data_source, video]          video(video)
# 30  [id, conversations, data_source, video]          video(video)
# 31  [id, conversations, data_source, video]          video(video)
# 32  [id, conversations, data_source, video]          video(video)
# 33  [id, conversations, data_source, video]          video(video)
# 34  [id, conversations, data_source, video]          video(video)
# 35                                       []                <none>
# 36  [id, conversations, data_source, video]          video(video)
# 37  [id, conversations, data_source, video]          video(video)
# 38  [id, conversations, data_source, video]       <none_detected>
#
#           formats_inferred                                     sample_preview  \
# 0   {'video': {'.mp4': 1}}  {'id': '028CE', 'conversations': [{'from': 'hu...
# 1   {'video': {'.mp4': 1}}  {'id': '028CE', 'conversations': [{'from': 'hu...
# 2   {'video': {'.mp4': 1}}  {'id': 'RW587', 'conversations': [{'from': 'hu...
# 3   {'video': {'.mp4': 1}}  {'id': '8bqHXtRirm4', 'conversations': [{'from...
# 4   {'video': {'.mp4': 1}}  {'id': '8bqHXtRirm4', 'conversations': [{'from...
# 5   {'video': {'.mp4': 1}}  {'id': 'YVQwAEKZpaU', 'conversations': [{'from...
# 6                       {}                                                 {}
# 7   {'video': {'.mp4': 1}}  {'id': 'perceptiontest_video_2779', 'conversat...
# 8   {'video': {'.mp4': 1}}  {'id': '1102-8903248754', 'conversations': [{'...
# 9   {'video': {'.mp4': 1}}  {'id': '1006-8968804598', 'conversations': [{'...
# 10  {'video': {'.mp4': 1}}  {'id': 'Q04US', 'conversations': [{'from': 'hu...
# 11  {'video': {'.mp4': 1}}  {'id': 'Q04US', 'conversations': [{'from': 'hu...
# 12  {'video': {'.mp4': 1}}  {'id': 'W4C5O', 'conversations': [{'from': 'hu...
# 13  {'video': {'.mp4': 1}}  {'id': '4V1vnSvwqvA', 'conversations': [{'from...
# 14  {'video': {'.mp4': 1}}  {'id': '4V1vnSvwqvA', 'conversations': [{'from...
# 15  {'video': {'.mp4': 1}}  {'id': 'fYs8TtubjMU', 'conversations': [{'from...
# 16                      {}                                                 {}
# 17  {'video': {'.mp4': 1}}  {'id': 'perceptiontest_video_9431', 'conversat...
# 18  {'video': {'.mp4': 1}}  {'id': '1009-4177168857', 'conversations': [{'...
# 19  {'video': {'.mp4': 1}}  {'id': '0071-2617504308', 'conversations': [{'...
# 20  {'video': {'.mp4': 1}}  {'id': '0vLOylUefFk', 'conversations': [{'from...
# 21  {'video': {'.mp4': 1}}  {'id': '0vLOylUefFk', 'conversations': [{'from...
# 22  {'video': {'.mp4': 1}}  {'id': '_nUy2Oaf27w', 'conversations': [{'from...
# 23  {'video': {'.mp4': 1}}  {'id': 'v_nw8MpBwL508', 'conversations': [{'fr...
# 24  {'video': {'.mp4': 1}}  {'id': 'v_nw8MpBwL508', 'conversations': [{'fr...
# 25  {'video': {'.mp4': 1}}  {'id': 'v_bpB0GiH6uDw', 'conversations': [{'fr...
# 26                      {}                                                 {}
# 27  {'video': {'.mp4': 1}}  {'id': '1164-3238737531', 'conversations': [{'...
# 28  {'video': {'.mp4': 1}}  {'id': '1122-7417682572', 'conversations': [{'...
# 29  {'video': {'.mp4': 1}}  {'id': '0oEz6UrT9Ro', 'conversations': [{'from...
# 30  {'video': {'.mp4': 1}}  {'id': '0oEz6UrT9Ro', 'conversations': [{'from...
# 31  {'video': {'.mp4': 1}}  {'id': 'MCYTTbFJhzY', 'conversations': [{'from...
# 32  {'video': {'.mp4': 1}}  {'id': 'v_YnvefOl6a7k', 'conversations': [{'fr...
# 33  {'video': {'.mp4': 1}}  {'id': 'v_YnvefOl6a7k', 'conversations': [{'fr...
# 34  {'video': {'.mp4': 1}}  {'id': 'v_yEFS8M4pgMU', 'conversations': [{'fr...
# 35                      {}                                                 {}
# 36  {'video': {'.mp4': 1}}  {'id': '1016-11049178966', 'conversations': [{...
# 37  {'video': {'.mp4': 1}}  {'id': '0075-12843838795', 'conversations': [{...
# 38                      {}  {'id': 'v_XNTy5ZTMqVU-Scene-011_1', 'conversat...
#
#     status                                              error
# 0       OK                                               None
# 1       OK                                               None
# 2       OK                                               None
# 3       OK                                               None
# 4       OK                                               None
# 5       OK                                               None
# 6   FAILED  Streaming failed: StopIteration (empty stream)...
# 7       OK                                               None
# 8       OK                                               None
# 9       OK                                               None
# 10      OK                                               None
# 11      OK                                               None
# 12      OK                                               None
# 13      OK                                               None
# 14      OK                                               None
# 15      OK                                               None
# 16  FAILED  Streaming failed: StopIteration (empty stream)...
# 17      OK                                               None
# 18      OK                                               None
# 19      OK                                               None
# 20      OK                                               None
# 21      OK                                               None
# 22      OK                                               None
# 23      OK                                               None
# 24      OK                                               None
# 25      OK                                               None
# 26  FAILED  Streaming failed: StopIteration (empty stream)...
# 27      OK                                               None
# 28      OK                                               None
# 29      OK                                               None
# 30      OK                                               None
# 31      OK                                               None
# 32      OK                                               None
# 33      OK                                               None
# 34      OK                                               None
# 35  FAILED  Streaming failed: StopIteration (empty stream)...
# 36      OK                                               None
# 37      OK                                               None
# 38      OK                                               None

# %%
from __future__ import annotations

import os
from pathlib import Path
from typing import Optional, Dict, Any, List

from huggingface_hub import hf_hub_download
from PIL import Image as PILImage
from IPython.display import display

DATASET_REPO_ID = "lmms-lab/LLaVA-Video-178K"
LOCAL_VIDEO_DIR = Path("./hf_videos_cache")   # change to your scratch dir on IBEX
LOCAL_VIDEO_DIR.mkdir(parents=True, exist_ok=True)

def resolve_video_path_from_hf(video_relpath: str) -> Optional[str]:
    """
    Given a relative path stored in the dataset row, try:
      - local path (if already present)
      - HF Hub download (dataset repo file)
    Returns a local filesystem path, or None.
    """
    # 1) already local?
    if os.path.exists(video_relpath):
        return video_relpath

    # 2) maybe it exists under our chosen cache dir with same relative structure
    candidate = LOCAL_VIDEO_DIR / video_relpath
    if candidate.exists():
        return str(candidate)

    # 3) download from the dataset repo
    try:
        local_file = hf_hub_download(
            repo_id=DATASET_REPO_ID,
            repo_type="dataset",
            filename=video_relpath,          # IMPORTANT: use the exact relative path
            local_dir=str(LOCAL_VIDEO_DIR),  # keep mirrored structure
            local_dir_use_symlinks=False,
        )
        return local_file
    except Exception as e:
        print("hf_hub_download failed for:", video_relpath)
        print("  ", repr(e))
        return None

def decode_random_frames(video_path: str, num_frames=3, seed=123) -> List[PILImage.Image]:
    import random
    import decord
    from decord import VideoReader, cpu

    vr = VideoReader(video_path, ctx=cpu(0))
    total = len(vr)
    if total == 0:
        return []

    rng = random.Random(seed + hash(video_path) % 10_000_000)
    if total <= num_frames:
        idxs = list(range(total))
    else:
        idxs = sorted(rng.sample(range(total), num_frames))

    imgs = []
    for idx in idxs:
        frame = vr[idx].asnumpy()
        imgs.append(PILImage.fromarray(frame))
    return imgs

def visualize_row(ex: Dict[str, Any], frames_per_video=3):
    video_val = ex.get("video")
    if isinstance(video_val, dict) and isinstance(video_val.get("path"), str):
        video_rel = video_val["path"]
    else:
        video_rel = video_val if isinstance(video_val, str) else None

    print("id:", ex.get("id"))
    print("data_source:", ex.get("data_source"))
    print("video (rel):", video_rel)

    if not video_rel:
        print("No video field.")
        return

    local_video = resolve_video_path_from_hf(video_rel)
    print("video (local):", local_video)

    if not local_video:
        print("Could not resolve video file; skipping.")
        return

    try:
        frames = decode_random_frames(local_video, num_frames=frames_per_video)
        for im in frames:
            display(im)
    except Exception as e:
        print("Frame decode failed:", repr(e))

# %%
from __future__ import annotations

import math
import os
import random
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple

import pandas as pd
from datasets import load_dataset, get_dataset_config_names
from huggingface_hub import hf_hub_download, list_repo_files
from PIL import Image as PILImage
from IPython.display import display

# =========================
# Config
# =========================
DATASET_ID = "lmms-lab/LLaVA-Video-178K"
TASK_SPLITS = ["caption", "open_ended", "multi_choice"]

SEED = 123
MAX_VIZ_PER_SPLIT = 12
FRAMES_PER_VIDEO = 3

# Put on fast storage (IBEX scratch recommended)
LOCAL_VIDEO_DIR = Path("./hf_videos_cache")
LOCAL_VIDEO_DIR.mkdir(parents=True, exist_ok=True)

VIDEO_EXTS = {".mp4", ".webm", ".mkv", ".mov", ".avi", ".m4v"}

# =========================
# Sampling scheme
# =========================
def sample_fraction(n: int) -> float:
    if n <= 10_000:
        return 0.01
    if n <= 100_000:
        return 0.001
    if n <= 1_000_000:
        return 0.0001
    if n <= 10_000_000:
        return 0.00001
    return 0.000001

def choose_sample_indices(n: int, k: int, seed=SEED) -> List[int]:
    rng = random.Random(seed)
    if k >= n:
        return list(range(n))
    return rng.sample(range(n), k)

# =========================
# Video helpers
# =========================
def get_video_relpath(ex: Dict[str, Any], field="video") -> Optional[str]:
    v = ex.get(field)
    if isinstance(v, str):
        return v
    if isinstance(v, dict) and isinstance(v.get("path"), str):
        return v["path"]
    return None

def decode_random_frames(video_path: str, num_frames=FRAMES_PER_VIDEO, seed=SEED) -> List[PILImage.Image]:
    import decord
    from decord import VideoReader, cpu

    vr = VideoReader(video_path, ctx=cpu(0))
    total = len(vr)
    if total <= 0:
        return []

    rng = random.Random(seed + (hash(video_path) % 10_000_000))
    if total <= num_frames:
        idxs = list(range(total))
    else:
        idxs = sorted(rng.sample(range(total), num_frames))

    imgs = []
    for idx in idxs:
        frame = vr[idx].asnumpy()
        imgs.append(PILImage.fromarray(frame))
    return imgs

# =========================
# 1-time HF repo index
# =========================
print("Indexing repo files from HF (one-time)...")
repo_files = list_repo_files(repo_id=DATASET_ID, repo_type="dataset")

# keep only video-like files (you can broaden this if needed)
hf_video_files = set(
    f for f in repo_files
    if os.path.splitext(f)[1].lower() in VIDEO_EXTS
)

print(f"HF repo files: {len(repo_files):,} | video files indexed: {len(hf_video_files):,}")

def resolve_video_to_local(video_relpath: str) -> Tuple[Optional[str], str]:
    """
    Fast resolver:
      - if not present in HF index => MISSING_ON_HF (no download attempt)
      - if present => download into LOCAL_VIDEO_DIR and return local path
    """
    # already local?
    if os.path.exists(video_relpath):
        return video_relpath, "OK_LOCAL"

    # cached in our local dir with same relative structure?
    candidate = LOCAL_VIDEO_DIR / video_relpath
    if candidate.exists():
        return str(candidate), "OK_CACHED"

    # If HF doesn't have it, skip immediately
    if video_relpath not in hf_video_files:
        return None, "MISSING_ON_HF"

    # Download (should succeed if index is correct)
    try:
        local_file = hf_hub_download(
            repo_id=DATASET_ID,
            repo_type="dataset",
            filename=video_relpath,
            local_dir=str(LOCAL_VIDEO_DIR),
            etag_timeout=10,  # avoid hanging too long on metadata
        )
        return local_file, "OK_DOWNLOADED"
    except Exception as e:
        return None, f"DOWNLOAD_ERROR: {type(e).__name__}"

# =========================
# Main loop (no transcript printing)
# =========================
configs = get_dataset_config_names(DATASET_ID)

summary_rows = []

for cfg in configs:
    for split in TASK_SPLITS:
        # load split to get exact N and to sample indices
        try:
            ds = load_dataset(DATASET_ID, name=cfg, split=split)
        except Exception as e:
            summary_rows.append({
                "config": cfg, "split": split, "N": None,
                "status": "SKIPPED", "error": repr(e)[:250],
            })
            continue

        N = ds.num_rows
        if N == 0:
            summary_rows.append({
                "config": cfg, "split": split, "N": 0,
                "status": "EMPTY", "error": None,
            })
            continue

        frac = sample_fraction(N)
        k = max(1, int(math.ceil(N * frac)))
        k_viz = min(k, MAX_VIZ_PER_SPLIT)
        idxs = choose_sample_indices(N, k_viz, seed=SEED)

        print("\n" + "=" * 110)
        print(f"CONFIG={cfg} | SPLIT={split} | N={N} | frac={frac} | sample_k={k} | viz={k_viz}")
        print("=" * 110)

        ok_viz = 0
        missing = 0
        dl_err = 0

        for j, ix in enumerate(idxs):
            ex = ds[ix]
            vid_rel = get_video_relpath(ex, field="video")

            print(f"\n--- sample {j+1}/{k_viz} (row={ix}) ---")
            print("id:", ex.get("id"))
            print("data_source:", ex.get("data_source"))
            print("video_rel:", vid_rel)

            if not vid_rel:
                print("No video relpath; skipping.")
                continue

            local_vid, status = resolve_video_to_local(vid_rel)
            print("resolve_status:", status)

            if status == "MISSING_ON_HF":
                missing += 1
                continue
            if local_vid is None:
                dl_err += 1
                continue

            try:
                frames = decode_random_frames(local_vid, num_frames=FRAMES_PER_VIDEO)
                if not frames:
                    print("No frames decoded.")
                for im in frames:
                    display(im)
                ok_viz += 1
            except Exception as e:
                print("Frame decode failed:", repr(e))

        summary_rows.append({
            "config": cfg,
            "split": split,
            "N": N,
            "fraction": frac,
            "sample_k": k,
            "viz": k_viz,
            "viz_ok": ok_viz,
            "missing_on_hf": missing,
            "download_errors": dl_err,
            "status": "OK",
            "error": None,
        })

summary_df = pd.DataFrame(summary_rows).sort_values(["config", "split"]).reset_index(drop=True)
summary_df
# Out:
# Indexing repo files from HF (one-time)...
# HF repo files: 302 | video files indexed: 1
#
# ==============================================================================================================
# CONFIG=0_30_s_academic_v0_1 | SPLIT=caption | N=11985 | frac=0.001 | sample_k=12 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=857) ---
# id: 323--sQXBqu-_1w-split_3
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/323/-sQXBqu-_1w/split_3.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=4385) ---
# id: MVO1W
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/MVO1W.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=1428) ---
# id: 1001-3013532781
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/NextQA/1001/3013532781.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=6672) ---
# id: ZS2WD
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/ZS2WD.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=4367) ---
# id: DTNFC
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/DTNFC.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=1764) ---
# id: 221-UB1_MNpdvgs-split_9
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/221/UB1_MNpdvgs/split_9.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=625) ---
# id: 308-XEHUV09m7Ok-split_4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/308/XEHUV09m7Ok/split_4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=6211) ---
# id: RLS2I
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/RLS2I.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=8785) ---
# id: YUEB9
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/YUEB9.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=9213) ---
# id: H2ZYY
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/H2ZYY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=5442) ---
# id: 305-fznTL6TzsqI-split_10
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/305/fznTL6TzsqI/split_10.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=5583) ---
# id: 1201-8954271057
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/NextQA/1201/8954271057.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_academic_v0_1 | SPLIT=open_ended | N=48468 | frac=0.001 | sample_k=49 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=3431) ---
# id: 318-XeXQ23fgS38-split_4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/318/XeXQ23fgS38/split_4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=17542) ---
# id: 409-MTGYZIE9nUo-split_9
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/409/MTGYZIE9nUo/split_9.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=5713) ---
# id: V4HY4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/V4HY4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=26688) ---
# id: 405-QWXlKD-XGCQ-split_2
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/405/QWXlKD-XGCQ/split_2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=17468) ---
# id: 310-zuDJIPoSl7o-split_2
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/310/zuDJIPoSl7o/split_2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=7058) ---
# id: 206-oaOdliOVL6g-split_2
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/206/oaOdliOVL6g/split_2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=2500) ---
# id: 305-UvuV9z3HkDo-split_7
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/305/UvuV9z3HkDo/split_7.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=24846) ---
# id: 302-iQjNhG92hr4-split_4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/302/iQjNhG92hr4/split_4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=35140) ---
# id: 318-bpogVeh1pRw-split_1
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/318/bpogVeh1pRw/split_1.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=36852) ---
# id: 121-fEN_fm6kX6k-split_4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/121/fEN_fm6kX6k/split_4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=21770) ---
# id: v_y1IjkACdnfs
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/activitynet/v_y1IjkACdnfs.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=22334) ---
# id: I6PBQ
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/I6PBQ.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_academic_v0_1 | SPLIT=multi_choice | N=5753 | frac=0.01 | sample_k=58 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=428) ---
# id: 112-J6j0B9hK2Sk-split_8
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/112/J6j0B9hK2Sk/split_8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=2192) ---
# id: 405-ox6YzyVQww0-split_4
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/405/ox6YzyVQww0/split_4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=714) ---
# id: 413-We4NsM_moJQ-split_9
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/413/We4NsM_moJQ/split_9.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=3336) ---
# id: 109-N6J2ZQYic_g-split_2
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/109/N6J2ZQYic_g/split_2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=2183) ---
# id: 416-LA6DXaQ5vGQ-split_3
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/416/LA6DXaQ5vGQ/split_3.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=882) ---
# id: 202-JfLGO_437iI-split_2
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/202/JfLGO_437iI/split_2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=312) ---
# id: 117-DDRzeomsyzU-split_3
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/117/DDRzeomsyzU/split_3.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=3105) ---
# id: 230-tU1NCC3KOOE-split_1
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/230/tU1NCC3KOOE/split_1.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=4392) ---
# id: 205-KCIGy7lt_Og-split_5
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/205/KCIGy7lt_Og/split_5.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=4606) ---
# id: 221-WRtoMalV4Zo-split_1
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/221/WRtoMalV4Zo/split_1.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=2721) ---
# id: X28IF
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/Charades/X28IF.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=2791) ---
# id: 301-0hVAuvPAIzA-split_5
# data_source: 0_30_s_academic_v0_1
# video_rel: academic_source/youcook2/301/0hVAuvPAIzA/split_5.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_youtube_v0_1 | SPLIT=caption | N=79346 | frac=0.001 | sample_k=80 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=6863) ---
# id: 4jk1B6PnX7I
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_4jk1B6PnX7I.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=35084) ---
# id: 1YbYzLjnL4c
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_1YbYzLjnL4c.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=11427) ---
# id: yGqhZE0KZTY
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_yGqhZE0KZTY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=53377) ---
# id: SOEFXDOrcV4
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_SOEFXDOrcV4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=34937) ---
# id: YS_8VIDjksc
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_YS_8VIDjksc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=14116) ---
# id: ev2KHJcIp5k
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_ev2KHJcIp5k.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=5000) ---
# id: JnSjQC9wINg
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_JnSjQC9wINg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=49692) ---
# id: z1wPjx9ONlo
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_z1wPjx9ONlo.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=70281) ---
# id: 4rUcUrXYLmA
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_4rUcUrXYLmA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=73704) ---
# id: eht-Ul6xztA
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_eht-Ul6xztA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=43541) ---
# id: gcRrGg3_3ts
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_gcRrGg3_3ts.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=44669) ---
# id: ntUuz9ppL4E
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_ntUuz9ppL4E.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_youtube_v0_1 | SPLIT=open_ended | N=420200 | frac=0.0001 | sample_k=43 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=27453) ---
# id: Qrrjt-DH0zA
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Qrrjt-DH0zA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=140339) ---
# id: PzcJm_SiblY
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_PzcJm_SiblY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=45710) ---
# id: rlHfL2fLvgw
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_rlHfL2fLvgw.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=403154) ---
# id: OrHgGZPo1Tg
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_OrHgGZPo1Tg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=213511) ---
# id: F3JpwuSKkMc
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_F3JpwuSKkMc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=139750) ---
# id: ge4gqNmgRc0
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_ge4gqNmgRc0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=56465) ---
# id: XDIEXbsGRAs
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_XDIEXbsGRAs.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=20003) ---
# id: NJIZ4aCZulQ
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_NJIZ4aCZulQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=198770) ---
# id: BtKGBTb_9Ag
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_BtKGBTb_9Ag.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=281124) ---
# id: B4iH6vkwz2Q
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_B4iH6vkwz2Q.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=294816) ---
# id: 6No_Tgudbks
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_6No_Tgudbks.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=174167) ---
# id: YzNlYeQUxZo
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_YzNlYeQUxZo.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_youtube_v0_1 | SPLIT=multi_choice | N=39353 | frac=0.001 | sample_k=40 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=3431) ---
# id: zw9j5PhhuwQ
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_zw9j5PhhuwQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=17542) ---
# id: 680Ihlqrit0
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_680Ihlqrit0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=5713) ---
# id: er9u_evTSzY
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_er9u_evTSzY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=26688) ---
# id: 52fwZPgxpA4
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_52fwZPgxpA4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=17468) ---
# id: 2EYHOFd5KG0
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_2EYHOFd5KG0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=7058) ---
# id: TjyXyjj3Dxg
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_TjyXyjj3Dxg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=2500) ---
# id: yrp4050AO6s
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_yrp4050AO6s.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=24846) ---
# id: IVAcuxSsdSw
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_IVAcuxSsdSw.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=35140) ---
# id: 2dvNAr9mksQ
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_2dvNAr9mksQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=36852) ---
# id: LQLv7F668IU
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_LQLv7F668IU.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=21770) ---
# id: 8KltBrGs6qA
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_8KltBrGs6qA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=22334) ---
# id: D_9f6Mku8c0
# data_source: 0_30_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_D_9f6Mku8c0.mp4
# resolve_status: MISSING_ON_HF
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# ==============================================================================================================
# CONFIG=0_30_s_perceptiontest | SPLIT=multi_choice | N=1785 | frac=0.01 | sample_k=18 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=107) ---
# id: perceptiontest_video_7656
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_7656.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=548) ---
# id: perceptiontest_video_10216
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_10216.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=178) ---
# id: perceptiontest_video_6080
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_6080.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=1574) ---
# id: perceptiontest_video_3275
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_3275.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=834) ---
# id: perceptiontest_video_11039
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_11039.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=545) ---
# id: perceptiontest_video_8553
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_8553.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=220) ---
# id: perceptiontest_video_4839
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_4839.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=1717) ---
# id: perceptiontest_video_5716
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_5716.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=78) ---
# id: perceptiontest_video_7565
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_7565.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=776) ---
# id: perceptiontest_video_9973
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_9973.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=1098) ---
# id: perceptiontest_video_9885
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_9885.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=1151) ---
# id: perceptiontest_video_1410
# data_source: 0_30_s_perceptiontest
# video_rel: perception_test/videos/video_1410.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_nextqa | SPLIT=open_ended | N=5492 | frac=0.01 | sample_k=55 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=428) ---
# id: 1002-4072482970
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1002/4072482970.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=2192) ---
# id: 1009-3759767103
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1009/3759767103.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=714) ---
# id: 1011-4078377816
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1011/4078377816.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=3336) ---
# id: 1150-5504106604
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1150/5504106604.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=2183) ---
# id: 1024-6774795741
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1024/6774795741.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=882) ---
# id: 0055-3360586484
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0055/3360586484.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=312) ---
# id: 0066-4438105322
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0066/4438105322.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=3105) ---
# id: 0100-5078580976
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0100/5078580976.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=4392) ---
# id: 1150-4772810451
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1150/4772810451.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=4606) ---
# id: 1019-8995779759
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1019/8995779759.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=2721) ---
# id: 1006-3616966959
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1006/3616966959.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=2791) ---
# id: 1023-4940333006
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1023/4940333006.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=0_30_s_nextqa | SPLIT=multi_choice | N=5496 | frac=0.01 | sample_k=55 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=428) ---
# id: 1103-4753074672
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1103/4753074672.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=2192) ---
# id: 1202-2554619666
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1202/2554619666.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=714) ---
# id: 0032-10315129403
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0032/10315129403.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=3336) ---
# id: 1014-2990913920
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1014/2990913920.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=2183) ---
# id: 1023-8295398331
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1023/8295398331.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=882) ---
# id: 1000-5126634355
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1000/5126634355.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=312) ---
# id: 0067-2885656050
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0067/2885656050.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=3105) ---
# id: 1006-3616966959
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1006/3616966959.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=4392) ---
# id: 0008-3762233206
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0008/3762233206.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=4606) ---
# id: 1015-2774585614
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1015/2774585614.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=2721) ---
# id: 1105-6239155123
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/1105/6239155123.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=2791) ---
# id: 0061-4354621230
# data_source: 0_30_s_nextqa
# video_rel: NextQA/NExTVideo/0061/4354621230.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_academic_v0_1 | SPLIT=caption | N=10514 | frac=0.001 | sample_k=11 | viz=11
# ==============================================================================================================
#
# --- sample 1/11 (row=857) ---
# id: 1100-3952344582
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/NextQA/1100/3952344582.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/11 (row=4385) ---
# id: 310-4UDMcBe5D3A-split_3
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/youcook2/310/4UDMcBe5D3A/split_3.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/11 (row=1428) ---
# id: 457bcdd9-c1db-40c5-a3fc-a9843d13219e
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/ego4d/457bcdd9-c1db-40c5-a3fc-a9843d13219e.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/11 (row=6672) ---
# id: 7H7PN
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/7H7PN.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/11 (row=4367) ---
# id: 1Q4SL
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/1Q4SL.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/11 (row=1764) ---
# id: 2JKR8
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/2JKR8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/11 (row=625) ---
# id: v_tik7rHU_DM8
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/activitynet/v_tik7rHU_DM8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/11 (row=6211) ---
# id: ZOLVU
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/ZOLVU.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/11 (row=8785) ---
# id: 303-GnbcTbVhG10-split_5
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/youcook2/303/GnbcTbVhG10/split_5.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/11 (row=9213) ---
# id: 9RA4P
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/9RA4P.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/11 (row=5442) ---
# id: X0JKJ
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/X0JKJ.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_academic_v0_1 | SPLIT=open_ended | N=57924 | frac=0.001 | sample_k=58 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=3431) ---
# id: 27SS2
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/27SS2.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=17542) ---
# id: 0052-2422024081
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/NextQA/0052/2422024081.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=5713) ---
# id: 2XXH8
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/2XXH8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=50394) ---
# id: 1005-10756878424
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/NextQA/1005/10756878424.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=26688) ---
# id: 211-KIvxQGWU5KU-split_5
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/youcook2/211/KIvxQGWU5KU/split_5.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=17468) ---
# id: MPUJ7
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/MPUJ7.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=7058) ---
# id: v_9RAW6QibWRs
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/activitynet/v_9RAW6QibWRs.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=54952) ---
# id: 6E8GP
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/6E8GP.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=57332) ---
# id: XMYXI
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/XMYXI.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=2500) ---
# id: 305-QtpJZHeoLGs-split_7
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/youcook2/305/QtpJZHeoLGs/split_7.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=24846) ---
# id: v_y8RpTBtGG1g
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/activitynet/v_y8RpTBtGG1g.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=35140) ---
# id: FYYFX
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/FYYFX.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_academic_v0_1 | SPLIT=multi_choice | N=20346 | frac=0.001 | sample_k=21 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=1715) ---
# id: v_HSEnmPWF5GY
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/activitynet/v_HSEnmPWF5GY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=8771) ---
# id: IC89C
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/IC89C.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=2856) ---
# id: 1013-3427096115
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/NextQA/1013/3427096115.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=13344) ---
# id: YBZOU
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/YBZOU.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=8734) ---
# id: 0034-5379354799
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/NextQA/0034/5379354799.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=3529) ---
# id: G3K2N
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/G3K2N.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=1250) ---
# id: OKHVL
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/OKHVL.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=12423) ---
# id: v_bH6KL0ai3Ww
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/activitynet/v_bH6KL0ai3Ww.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=17570) ---
# id: DE8T8
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/DE8T8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=18426) ---
# id: YQCYJ
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/YQCYJ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=10885) ---
# id: EQ4GN
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/EQ4GN.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=11167) ---
# id: GRYTY
# data_source: 30_60_s_academic_v0_1
# video_rel: academic_source/Charades/GRYTY.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_youtube_v0_1 | SPLIT=caption | N=19995 | frac=0.001 | sample_k=20 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=1715) ---
# id: ek-ncyfaH-Y
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_ek-ncyfaH-Y.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=8771) ---
# id: qG68L9TEBZ0
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_qG68L9TEBZ0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=2856) ---
# id: hkeClKqXTcU
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_hkeClKqXTcU.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=13344) ---
# id: TxWhg-Wg61c
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_TxWhg-Wg61c.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=8734) ---
# id: 4sBITGKQ_GM
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_4sBITGKQ_GM.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=3529) ---
# id: gQNjMssDtcc
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_gQNjMssDtcc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=1250) ---
# id: rtBt-xqUvpA
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_rtBt-xqUvpA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=12423) ---
# id: EuRBM0i8mbI
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_EuRBM0i8mbI.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=17570) ---
# id: iwXCT7NCbGU
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_iwXCT7NCbGU.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=18426) ---
# id: kr4LHRyr50k
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_kr4LHRyr50k.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=10885) ---
# id: 3Q8VUftI3ZA
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_3Q8VUftI3ZA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=11167) ---
# id: Q_KzJIzsg00
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Q_KzJIzsg00.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_youtube_v0_1 | SPLIT=open_ended | N=110624 | frac=0.0001 | sample_k=12 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=6863) ---
# id: e4nwzXS2-IY
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_e4nwzXS2-IY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=35084) ---
# id: 4bnyp-3i26E
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_4bnyp-3i26E.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=11427) ---
# id: 7wBkTGNGzJA
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_7wBkTGNGzJA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=100788) ---
# id: 95QUyayC_UM
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_95QUyayC_UM.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=53377) ---
# id: Rl4dVy8Ghs8
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Rl4dVy8Ghs8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=34937) ---
# id: WHnOlEIiPtw
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_WHnOlEIiPtw.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=14116) ---
# id: RLuw7_xT17o
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_RLuw7_xT17o.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=109904) ---
# id: nWWXZ8dUV2E
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_nWWXZ8dUV2E.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=5000) ---
# id: yGQUvvt59bs
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_yGQUvvt59bs.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=49692) ---
# id: DTOSNJzQKD0
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_DTOSNJzQKD0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=70281) ---
# id: Xj2WQwdzBVg
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Xj2WQwdzBVg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=73704) ---
# id: qabdYHGU0Hs
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_qabdYHGU0Hs.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_youtube_v0_1 | SPLIT=multi_choice | N=39927 | frac=0.001 | sample_k=40 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=3431) ---
# id: QwOsNuPOPXQ
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_QwOsNuPOPXQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=17542) ---
# id: yX1jP-odIS0
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_yX1jP-odIS0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=5713) ---
# id: _zskg39Z9jQ
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb__zskg39Z9jQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=26688) ---
# id: NaDF4hUpiRA
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_NaDF4hUpiRA.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=17468) ---
# id: jHQf-olyyGY
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_jHQf-olyyGY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=7058) ---
# id: mV7ib8VRCi4
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_mV7ib8VRCi4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=2500) ---
# id: _QXccnkSnWY
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb__QXccnkSnWY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=24846) ---
# id: vFFatN7RnUo
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_vFFatN7RnUo.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=35140) ---
# id: x4yrPLZhfFg
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_x4yrPLZhfFg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=36852) ---
# id: IYd_5NtqDOc
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_IYd_5NtqDOc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=21770) ---
# id: Adr9tYobOkc
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Adr9tYobOkc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=22334) ---
# id: gAj0eJPROyk
# data_source: 30_60_s_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_gAj0eJPROyk.mp4
# resolve_status: MISSING_ON_HF
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# ==============================================================================================================
# CONFIG=30_60_s_perceptiontest | SPLIT=multi_choice | N=618 | frac=0.01 | sample_k=7 | viz=7
# ==============================================================================================================
#
# --- sample 1/7 (row=53) ---
# id: perceptiontest_video_3215
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_3215.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/7 (row=274) ---
# id: perceptiontest_video_1614
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_1614.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/7 (row=89) ---
# id: perceptiontest_video_2867
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_2867.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/7 (row=417) ---
# id: perceptiontest_video_8989
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_8989.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/7 (row=272) ---
# id: perceptiontest_video_10212
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_10212.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/7 (row=110) ---
# id: perceptiontest_video_3928
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_3928.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/7 (row=39) ---
# id: perceptiontest_video_10145
# data_source: 30_60_s_perceptiontest
# video_rel: perception_test/videos/video_10145.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_nextqa | SPLIT=open_ended | N=6843 | frac=0.01 | sample_k=69 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=428) ---
# id: 1008-3640647736
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1008/3640647736.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=2192) ---
# id: 1020-2575032824
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1020/2575032824.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=714) ---
# id: 1018-4874416538
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1018/4874416538.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=6299) ---
# id: 1203-6461150811
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1203/6461150811.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=3336) ---
# id: 1001-4845474028
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1001/4845474028.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=2183) ---
# id: 1026-8802047883
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1026/8802047883.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=882) ---
# id: 1005-7631378506
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1005/7631378506.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=312) ---
# id: 1103-6188920051
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1103/6188920051.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=3105) ---
# id: 1002-4889389323
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1002/4889389323.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=4392) ---
# id: 0051-3702633786
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0051/3702633786.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=4606) ---
# id: 1130-8331705246
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1130/8331705246.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=2721) ---
# id: 0003-3054802852
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0003/3054802852.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=30_60_s_nextqa | SPLIT=multi_choice | N=6843 | frac=0.01 | sample_k=69 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=428) ---
# id: 1019-2978261607
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1019/2978261607.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=2192) ---
# id: 1008-4856339912
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1008/4856339912.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=714) ---
# id: 0084-4903182028
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0084/4903182028.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=6299) ---
# id: 1122-4301077635
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1122/4301077635.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=3336) ---
# id: 1202-3485644822
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1202/3485644822.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=2183) ---
# id: 1103-7174397959
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1103/7174397959.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=882) ---
# id: 1019-5223035448
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1019/5223035448.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=312) ---
# id: 1051-8059684971
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1051/8059684971.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=3105) ---
# id: 0022-3947186552
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0022/3947186552.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=4392) ---
# id: 1150-3028745389
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/1150/3028745389.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=4606) ---
# id: 0037-10682761273
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0037/10682761273.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=2721) ---
# id: 0090-3067691306
# data_source: 30_60_s_nextqa
# video_rel: NextQA/NExTVideo/0090/3067691306.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=1_2_m_youtube_v0_1 | SPLIT=caption | N=24234 | frac=0.001 | sample_k=25 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=1715) ---
# id: PTJA9sEdKU4
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/hdvila/PTJA9sEdKU4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=8771) ---
# id: OdahB-0dR3g
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_OdahB-0dR3g.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=2856) ---
# id: NZymAnGvqK4
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_NZymAnGvqK4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=13344) ---
# id: 55EgxIVlcvw
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_55EgxIVlcvw.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=8734) ---
# id: WVxj9OiUWpg
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_WVxj9OiUWpg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=3529) ---
# id: o1C5Xnf4v84
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_o1C5Xnf4v84.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=1250) ---
# id: 8dIjw0itgpg
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_8dIjw0itgpg.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=12423) ---
# id: kb9OcYqhW68
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_kb9OcYqhW68.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=17570) ---
# id: II2jpRu8JRQ
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/hdvila/II2jpRu8JRQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=18426) ---
# id: Cs3UYGEYqzc
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Cs3UYGEYqzc.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=10885) ---
# id: QcAR9WBXakQ
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/hdvila/QcAR9WBXakQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=11167) ---
# id: JKeceBpMenM
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_JKeceBpMenM.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=1_2_m_youtube_v0_1 | SPLIT=open_ended | N=137645 | frac=0.0001 | sample_k=14 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=13726) ---
# id: ttfJFCZLafs
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/hdvila/ttfJFCZLafs.mkv
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=70169) ---
# id: Bb3C4Nj_8k0
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_Bb3C4Nj_8k0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=22855) ---
# id: 7z6Lf2V1_JQ
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_7z6Lf2V1_JQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=106755) ---
# id: YA25GfeE_ds
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_YA25GfeE_ds.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=69875) ---
# id: HDVYH1RDmCE
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_HDVYH1RDmCE.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=28232) ---
# id: 0bGX9A6kR0k
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_0bGX9A6kR0k.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=10001) ---
# id: GBaGW_gFVb8
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_GBaGW_gFVb8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=99385) ---
# id: y9LajlJjd4E
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_y9LajlJjd4E.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=87083) ---
# id: hjwfFHytYO8
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_hjwfFHytYO8.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=89338) ---
# id: mXDlE8YdYZ0
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/hdvila/mXDlE8YdYZ0.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=13605) ---
# id: PKghk_zNH4c
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_PKghk_zNH4c.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=41854) ---
# id: hnI7IV71v-4
# data_source: 1_2_m_youtube_v0_1
# video_rel: liwei_youtube_videos/videos/youtube_video_2024/ytb_hnI7IV71v-4.mp4
# resolve_status: MISSING_ON_HF
#
# ...
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=3336) ---
# id: v_J4rzLO4u_pI
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_J4rzLO4u_pI.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=2183) ---
# id: v_UmuWttAYfco
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_UmuWttAYfco.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=882) ---
# id: v_6NqS3vYvf6Q
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_6NqS3vYvf6Q.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=6869) ---
# id: v_3S5RoKVsAys
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_3S5RoKVsAys.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=312) ---
# id: v_Tz5eN8gV6F4
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_Tz5eN8gV6F4.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=3105) ---
# id: v_Y75Fvr71aRQ
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_Y75Fvr71aRQ.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=4392) ---
# id: v_JtQSDGSKnsY
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_JtQSDGSKnsY.mp4
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=4606) ---
# id: v_uy7WAwrrNiA
# data_source: 2_3_m_academic_v0_1
# video_rel: academic_source/activitynet/v_uy7WAwrrNiA.mp4
# resolve_status: MISSING_ON_HF
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# Generating open_ended split: 0 examples [00:00, ? examples/s]
# ==============================================================================================================
# CONFIG=2_3_m_nextqa | SPLIT=open_ended | N=61 | frac=0.01 | sample_k=1 | viz=1
# ==============================================================================================================
#
# --- sample 1/1 (row=3) ---
# id: 1016-11049178966
# data_source: 2_3_m_nextqa
# video_rel: NextQA/NExTVideo/1016/11049178966.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=2_3_m_nextqa | SPLIT=multi_choice | N=52 | frac=0.01 | sample_k=1 | viz=1
# ==============================================================================================================
#
# --- sample 1/1 (row=3) ---
# id: 1013-10566292134
# data_source: 2_3_m_nextqa
# video_rel: NextQA/NExTVideo/1013/10566292134.mp4
# resolve_status: MISSING_ON_HF
#
# ==============================================================================================================
# CONFIG=llava_hound | SPLIT=open_ended | N=255000 | frac=0.0001 | sample_k=26 | viz=12
# ==============================================================================================================
#
# --- sample 1/12 (row=13726) ---
# id: v_3dR4MEUDHa0-Scene-011_0
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_3dR4MEUDHa0-Scene-011
# resolve_status: MISSING_ON_HF
#
# --- sample 2/12 (row=70169) ---
# id: v_lQP65cm11FA-Scene-003_2
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_lQP65cm11FA-Scene-003
# resolve_status: MISSING_ON_HF
#
# --- sample 3/12 (row=22855) ---
# id: v_zB8kwWJqQ8Q-Scene-008_1
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_zB8kwWJqQ8Q-Scene-008
# resolve_status: MISSING_ON_HF
#
# --- sample 4/12 (row=201577) ---
# id: 8070091_2
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/8070091
# resolve_status: MISSING_ON_HF
#
# --- sample 5/12 (row=106755) ---
# id: GFia5Zj1ATI_0
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/GFia5Zj1ATI
# resolve_status: MISSING_ON_HF
#
# --- sample 6/12 (row=69875) ---
# id: v_KMz8f9vDK38-Scene-001_2
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_KMz8f9vDK38-Scene-001
# resolve_status: MISSING_ON_HF
#
# --- sample 7/12 (row=28232) ---
# id: v_5yqHTGQm2B0-Scene-002_0
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_5yqHTGQm2B0-Scene-002
# resolve_status: MISSING_ON_HF
#
# --- sample 8/12 (row=219808) ---
# id: 1032774416_1
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/1032774416
# resolve_status: MISSING_ON_HF
#
# --- sample 9/12 (row=236243) ---
# id: 11926568_1
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/11926568
# resolve_status: MISSING_ON_HF
#
# --- sample 10/12 (row=229330) ---
# id: 1065091486_2
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/1065091486
# resolve_status: MISSING_ON_HF
#
# --- sample 11/12 (row=10001) ---
# id: v_Exu0qsz42fQ-Scene-002_1
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/v_Exu0qsz42fQ-Scene-002
# resolve_status: MISSING_ON_HF
#
# --- sample 12/12 (row=99385) ---
# id: r_d1Si2IQSY_0
# data_source: llava_hound
# video_rel: shareVideoGPTV/frames/all_frames/r_d1Si2IQSY
# resolve_status: MISSING_ON_HF
#                     config         split         N  fraction  sample_k   viz  \
# 0     0_30_s_academic_v0_1       caption   11985.0    0.0010      12.0  12.0
# 1     0_30_s_academic_v0_1  multi_choice    5753.0    0.0100      58.0  12.0
# 2     0_30_s_academic_v0_1    open_ended   48468.0    0.0010      49.0  12.0
# 3       0_30_s_activitynet       caption       NaN       NaN       NaN   NaN
# 4       0_30_s_activitynet  multi_choice       NaN       NaN       NaN   NaN
# 5       0_30_s_activitynet    open_ended       NaN       NaN       NaN   NaN
# 6            0_30_s_nextqa       caption       NaN       NaN       NaN   NaN
# 7            0_30_s_nextqa  multi_choice    5496.0    0.0100      55.0  12.0
# 8            0_30_s_nextqa    open_ended    5492.0    0.0100      55.0  12.0
# 9    0_30_s_perceptiontest       caption       NaN       NaN       NaN   NaN
# 10   0_30_s_perceptiontest  multi_choice    1785.0    0.0100      18.0  12.0
# 11   0_30_s_perceptiontest    open_ended       NaN       NaN       NaN   NaN
# 12     0_30_s_youtube_v0_1       caption   79346.0    0.0010      80.0  12.0
# 13     0_30_s_youtube_v0_1  multi_choice   39353.0    0.0010      40.0  12.0
# 14     0_30_s_youtube_v0_1    open_ended  420200.0    0.0001      43.0  12.0
# 15     1_2_m_academic_v0_1       caption    4627.0    0.0100      47.0  12.0
# 16     1_2_m_academic_v0_1  multi_choice    4241.0    0.0100      43.0  12.0
# 17     1_2_m_academic_v0_1    open_ended   26302.0    0.0010      27.0  12.0
# 18       1_2_m_activitynet       caption       NaN       NaN       NaN   NaN
# 19       1_2_m_activitynet  multi_choice       NaN       NaN       NaN   NaN
# 20       1_2_m_activitynet    open_ended       NaN       NaN       NaN   NaN
# 21            1_2_m_nextqa       caption       NaN       NaN       NaN   NaN
# 22            1_2_m_nextqa  multi_choice    4633.0    0.0100      47.0  12.0
# 23            1_2_m_nextqa    open_ended    4694.0    0.0100      47.0  12.0
# 24      1_2_m_youtube_v0_1       caption   24234.0    0.0010      25.0  12.0
# 25      1_2_m_youtube_v0_1  multi_choice   39710.0    0.0010      40.0  12.0
# 26      1_2_m_youtube_v0_1    open_ended  137645.0    0.0001      14.0  12.0
# 27     2_3_m_academic_v0_1       caption    3124.0    0.0100      32.0  12.0
# 28     2_3_m_academic_v0_1  multi_choice    6901.0    0.0100      70.0  12.0
# 29     2_3_m_academic_v0_1    open_ended   18134.0    0.0010      19.0  12.0
# 30       2_3_m_activitynet       caption       NaN       NaN       NaN   NaN
# 31       2_3_m_activitynet  multi_choice       NaN       NaN       NaN   NaN
# 32       2_3_m_activitynet    open_ended       NaN       NaN       NaN   NaN
# 33            2_3_m_nextqa       caption       NaN       NaN       NaN   NaN
# 34            2_3_m_nextqa  multi_choice      52.0    0.0100       1.0   1.0
# 35            2_3_m_nextqa    open_ended      61.0    0.0100       1.0   1.0
# 36      2_3_m_youtube_v0_1       caption   24685.0    0.0010      25.0  12.0
# 37      2_3_m_youtube_v0_1  multi_choice   39967.0    0.0010      40.0  12.0
# 38      2_3_m_youtube_v0_1    open_ended  141495.0    0.0001      15.0  12.0
# 39   30_60_s_academic_v0_1       caption   10514.0    0.0010      11.0  11.0
# 40   30_60_s_academic_v0_1  multi_choice   20346.0    0.0010      21.0  12.0
# 41   30_60_s_academic_v0_1    open_ended   57924.0    0.0010      58.0  12.0
# 42     30_60_s_activitynet       caption       NaN       NaN       NaN   NaN
# 43     30_60_s_activitynet  multi_choice       NaN       NaN       NaN   NaN
# 44     30_60_s_activitynet    open_ended       NaN       NaN       NaN   NaN
# 45          30_60_s_nextqa       caption       NaN       NaN       NaN   NaN
# 46          30_60_s_nextqa  multi_choice    6843.0    0.0100      69.0  12.0
# 47          30_60_s_nextqa    open_ended    6843.0    0.0100      69.0  12.0
# 48  30_60_s_perceptiontest       caption       NaN       NaN       NaN   NaN
# 49  30_60_s_perceptiontest  multi_choice     618.0    0.0100       7.0   7.0
# 50  30_60_s_perceptiontest    open_ended       NaN       NaN       NaN   NaN
# 51    30_60_s_youtube_v0_1       caption   19995.0    0.0010      20.0  12.0
# 52    30_60_s_youtube_v0_1  multi_choice   39927.0    0.0010      40.0  12.0
# 53    30_60_s_youtube_v0_1    open_ended  110624.0    0.0001      12.0  12.0
# 54             llava_hound       caption       NaN       NaN       NaN   NaN
# 55             llava_hound  multi_choice       NaN       NaN       NaN   NaN
# 56             llava_hound    open_ended  255000.0    0.0001      26.0  12.0
#
#     viz_ok  missing_on_hf  download_errors   status  \
# 0      0.0           12.0              0.0       OK
# 1      0.0           12.0              0.0       OK
# 2      0.0           12.0              0.0       OK
# 3      NaN            NaN              NaN  SKIPPED
# 4      NaN            NaN              NaN  SKIPPED
# 5      NaN            NaN              NaN  SKIPPED
# 6      NaN            NaN              NaN  SKIPPED
# 7      0.0           12.0              0.0       OK
# 8      0.0           12.0              0.0       OK
# 9      NaN            NaN              NaN  SKIPPED
# 10     0.0           12.0              0.0       OK
# 11     NaN            NaN              NaN  SKIPPED
# 12     0.0           12.0              0.0       OK
# 13     0.0           12.0              0.0       OK
# 14     0.0           12.0              0.0       OK
# 15     0.0           12.0              0.0       OK
# 16     0.0           12.0              0.0       OK
# 17     0.0           12.0              0.0       OK
# 18     NaN            NaN              NaN  SKIPPED
# 19     NaN            NaN              NaN  SKIPPED
# 20     NaN            NaN              NaN  SKIPPED
# 21     NaN            NaN              NaN  SKIPPED
# 22     0.0           12.0              0.0       OK
# 23     0.0           12.0              0.0       OK
# 24     0.0           12.0              0.0       OK
# 25     0.0           12.0              0.0       OK
# 26     0.0           12.0              0.0       OK
# 27     0.0           12.0              0.0       OK
# 28     0.0           12.0              0.0       OK
# 29     0.0           12.0              0.0       OK
# 30     NaN            NaN              NaN  SKIPPED
# 31     NaN            NaN              NaN  SKIPPED
# 32     NaN            NaN              NaN  SKIPPED
# 33     NaN            NaN              NaN  SKIPPED
# 34     0.0            1.0              0.0       OK
# 35     0.0            1.0              0.0       OK
# 36     0.0           12.0              0.0       OK
# 37     0.0           12.0              0.0       OK
# 38     0.0           12.0              0.0       OK
# 39     0.0           11.0              0.0       OK
# 40     0.0           12.0              0.0       OK
# 41     0.0           12.0              0.0       OK
# 42     NaN            NaN              NaN  SKIPPED
# 43     NaN            NaN              NaN  SKIPPED
# 44     NaN            NaN              NaN  SKIPPED
# 45     NaN            NaN              NaN  SKIPPED
# 46     0.0           12.0              0.0       OK
# 47     0.0           12.0              0.0       OK
# 48     NaN            NaN              NaN  SKIPPED
# 49     0.0            7.0              0.0       OK
# 50     NaN            NaN              NaN  SKIPPED
# 51     0.0           12.0              0.0       OK
# 52     0.0           12.0              0.0       OK
# 53     0.0           12.0              0.0       OK
# 54     NaN            NaN              NaN  SKIPPED
# 55     NaN            NaN              NaN  SKIPPED
# 56     0.0           12.0              0.0       OK
#
#                                                 error
# 0                                                None
# 1                                                None
# 2                                                None
# 3   DatasetGenerationError('An error occurred whil...
# 4   DatasetGenerationError('An error occurred whil...
# 5   DatasetGenerationError('An error occurred whil...
# 6   ValueError('Unknown split "caption". Should be...
# 7                                                None
# 8                                                None
# 9   ValueError('Unknown split "caption". Should be...
# 10                                               None
# 11  ValueError('Unknown split "open_ended". Should...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  DatasetGenerationError('An error occurred whil...
# 19  DatasetGenerationError('An error occurred whil...
# 20  DatasetGenerationError('An error occurred whil...
# 21  ValueError('Unknown split "caption". Should be...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30  DatasetGenerationError('An error occurred whil...
# 31  DatasetGenerationError('An error occurred whil...
# 32  DatasetGenerationError('An error occurred whil...
# 33  ValueError('Unknown split "caption". Should be...
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42  DatasetGenerationError('An error occurred whil...
# 43  DatasetGenerationError('An error occurred whil...
# 44  DatasetGenerationError('An error occurred whil...
# 45  ValueError('Unknown split "caption". Should be...
# 46                                               None
# 47                                               None
# 48  ValueError('Unknown split "caption". Should be...
# 49                                               None
# 50  ValueError('Unknown split "open_ended". Should...
# 51                                               None
# 52                                               None
# 53                                               None
# 54  ValueError('Unknown split "caption". Should be...
# 55  ValueError('Unknown split "multi_choice". Shou...
# 56                                               None
